# %% [markdown]
# <a href="https://www.kaggle.com/code/sunny2810/netflix-data-analysis?scriptVersionId=99152198" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def show_values_on_bars(axs, h_v="v", space=1):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %% [markdown]
# #  `Netflix - Data Exploration and Visualisation`

# %% [markdown]
# ## `insights that could help Netflix in deciding which type of shows/movies to produce and how they can grow the business in different countries`

# %%
df = pd.read_csv("../input/netflix-dataset/netflix.csv")

# %%
df["serial_no"] = [x for x in range(len(df))]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, serial_no]
# Index: []

# %% [markdown]
# ## base info about the data set:
#
# #### getting idea about the shape / data type info
#
# #### if there are missing data in columns

# %%
df.shape
# Out:
# (8807, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  serial_no     8807 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %% [markdown]
# ##### missing values per column in %:

# %%
(df.isna().sum()/len(df))*100 # %
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# serial_no        0.000000
# dtype: float64

# %%
# director column has 29% missing value
# for cast and countries 10% missing data

# %%
df["show_id"].duplicated().value_counts()
# Out:
# False    8807
# Name: show_id, dtype: int64

# %% [markdown]
# ###### no duplicate data

# %%
df.describe(include="object")
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %%
df.isna().sum().sum()  # total missing values in the data set
# Out:
# 4307

# %% [markdown]
# ##### replacing necessary null values

# %%
df["director"].fillna(value="Unknown", inplace=True)
df["cast"].fillna(value="Unknown", inplace=True)
df["country"].fillna(value="Unknown",inplace=True)

# %%
df.describe(include="object")
# Out:
#        show_id   type                 title director     cast        country  \
# count     8807   8807                  8807     8807     8807           8807
# unique    8807      2                  8807     4529     7693            749
# top         s1  Movie  Dick Johnson Is Dead  Unknown  Unknown  United States
# freq         1   6131                     1     2634      825           2818
#
#              date_added rating  duration                     listed_in  \
# count              8797   8803      8804                          8807
# unique             1767     17       220                           514
# top     January 1, 2020  TV-MA  1 Season  Dramas, International Movies
# freq                109   3207      1793                           362
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %% [markdown]
# ##### unique values per column:

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4529
# cast            7693
# country          749
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# serial_no       8807
# dtype: int64

# %% [markdown]
# ##### # converting data type of date_added to datetime format

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df.head().head(1)
# Out:
#   show_id   type                 title         director     cast  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  Unknown
#
#          country date_added  release_year rating duration      listed_in  \
# 0  United States 2021-09-25          2020  PG-13   90 min  Documentaries
#
#                                          description  serial_no
# 0  As her father nears the end of his life, filmm...          0

# %% [markdown]
# ###### dropping unnecessary columns

# %%
df.drop(["description"], axis=1 , inplace= True)

# %%
df.head(1)
# Out:
#   show_id   type                 title         director     cast  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  Unknown
#
#          country date_added  release_year rating duration      listed_in  \
# 0  United States 2021-09-25          2020  PG-13   90 min  Documentaries
#
#    serial_no
# 0          0

# %% [markdown]
# ##### extracting necessary freatures from already present data :
# ##### adding year and month data when content was added

# %%
df["year_added"] = df["date_added"].dt.year

# %%
df["month_added"]  = df["date_added"].dt.month_name()

# %% [markdown]
# #### seperating duration for TV shows and Movies and changing their data types

# %%
df["Movie_duration"] = df["duration"].loc[df["type"]=="Movie"]
df["Series_duration"] = df["duration"].loc[df["type"]=="TV Show"]

# %%
### changing data type and format of Mpvies_duratio to float
def split_duration(x):
    return str(x).split(" ")[0]

# %%
df["Movie_duration"] = df["Movie_duration"].apply(split_duration).astype("float")
df["Series_duration"] = df["Series_duration"].apply(split_duration).astype("float")

# %%
df.drop("duration",axis =1,inplace=True)

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          Unknown
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
#
#                                            listed_in  serial_no  year_added  \
# 0                                      Documentaries          0      2021.0
# 1    International TV Shows, TV Dramas, TV Mysteries          1      2021.0
# 2  Crime TV Shows, International TV Shows, TV Act...          2      2021.0
#
#   month_added  Movie_duration  Series_duration
# 0   September            90.0              NaN
# 1   September             NaN              2.0
# 2   September             NaN              1.0

# %% [markdown]
# ### `type of content on Netflix dataset`

# %%
df["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df["type"].value_counts(dropna=False)
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
moviesVSseries = df["type"].value_counts(normalize=True)*100
moviesVSseries
# Out:
# Movie      69.615079
# TV Show    30.384921
# Name: type, dtype: float64

# %%
sns.set(font_scale = 1)

# %%
types = sns.countplot(data = df , x = "type")


        
show_values_on_bars(types,h_v="v",space=1)

# %% [raw]
# # From the Neflix data :
# We have 70% content of Movies and 30% are TV Shows.

# %% [markdown]
# ### `Number of content per Rating`

# %%
df["Content_For"] = df["rating"].replace({"TV-MA":"Adults",
                     "TV-14" : "Teens",
                     "TV-PG" : "Older Kids",
                      "R":"Adults",
                      "PG-13":"Teens",
                      "TV-Y7":"Older Kids",
                      "TV-Y":"Kids",
                      "PG":"Older Kids",
                      "TV-G":"Kids",
                      "NR":"Adults",
                      "G":"Kids",
                      "TV-Y7-FV":"Older Kids",
                      "NC-17":"Adults",
                      "UR":"Adults"
                     
                    
                     })

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'listed_in', 'serial_no', 'year_added',
#        'month_added', 'Movie_duration', 'Series_duration', 'Content_For'],
#       dtype='object')

# %% [markdown]
# ##### number of Content each rating category has :

# %%
df["rating"].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
(df["rating"].value_counts(normalize=True)*100).head(11)
# Out:
# TV-MA    36.430762
# TV-14    24.537090
# TV-PG     9.803476
# R         9.076451
# PG-13     5.566284
# TV-Y7     3.794161
# TV-Y      3.487447
# PG        3.260252
# TV-G      2.499148
# NR        0.908781
# G         0.465750
# Name: rating, dtype: float64

# %%
(df["rating"].value_counts(normalize=True)*100).head(11).sum()

# 99.82% of content is from above rating list
# Out:
# 99.82960354424627

# %% [markdown]
# ##### 99.82% of content is from above rating list

# %%
most_frequent_ratings =  df["rating"].value_counts().sort_values(ascending=False).head(11).index
most_frequent_ratings
# Out:
# Index(['TV-MA', 'TV-14', 'TV-PG', 'R', 'PG-13', 'TV-Y7', 'TV-Y', 'PG', 'TV-G',
#        'NR', 'G'],
#       dtype='object')

# %%
ratings = df["rating"].value_counts().sort_values(ascending=False).head(11)

# %%
plt.figure(figsize=(8,5))
# sns.barplot(x=df["rating"].value_counts().head(11),y = df["rating"].value_counts().head(11).index)
show_values_on_bars(sns.barplot( x = df["rating"].value_counts().head(11),
                                y = df["rating"].value_counts().head(11).index)
                    ,h_v="h")
plt.xlabel("Number of Movie per Rating Category")
plt.ylabel("Rating Categories")
plt.show()

# %% [markdown]
# ##### Number of Contents present in data as per Age group :

# %%
df["Content_For"].value_counts().head()
# Out:
# Adults        4092
# Teens         2650
# Older Kids    1490
# Kids           568
# 74 min           1
# Name: Content_For, dtype: int64

# %%
df["Content_For"].value_counts(normalize=True)*100
# Out:
# Adults        46.484153
# Teens         30.103374
# Older Kids    16.926048
# Kids           6.452346
# 74 min         0.011360
# 84 min         0.011360
# 66 min         0.011360
# Name: Content_For, dtype: float64

# %% [raw]
#                                  46 % content is for adults
#                                  30% for teens
#                                  16% for older kids
#                                  6% for kids

# %%
plt.figure(figsize=(8,5))
show_values_on_bars(sns.countplot(x = df["Content_For"]))

# %% [markdown]
# ### `# number of movies released per year over last 30 years`

# %%
in_last_30_year_movie_released =  df.groupby("release_year")["title"].count().sort_values(ascending=True).tail(30).reset_index()

# %%
in_last_30_year_movie_released.columns
# Out:
# Index(['release_year', 'title'], dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.bar(in_last_30_year_movie_released["release_year"],in_last_30_year_movie_released["title"])

plt.xlabel("years")
plt.ylabel("number of content released per year")

# plt.xticks(20)
plt.xticks(np.arange(1990,2023,2),rotation = 90)


plt.show()

# %% [raw]
# # possibly because of pandemic , count of releasing movies has been decreased .

# %% [markdown]
# #### Recommendation :
#  It would be appropriate decision if we add content based on past data as per best actors and directors , or produce more movies specifically for Netflix .

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### working on multi_value data columns

# %%
# cast - director - country - listedIn(genres)

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          Unknown
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
#
#                                            listed_in  serial_no  year_added  \
# 0                                      Documentaries          0      2021.0
# 1    International TV Shows, TV Dramas, TV Mysteries          1      2021.0
# 2  Crime TV Shows, International TV Shows, TV Act...          2      2021.0
#
#   month_added  Movie_duration  Series_duration Content_For
# 0   September            90.0              NaN       Teens
# 1   September             NaN              2.0      Adults
# 2   September             NaN              1.0      Adults

# %% [markdown]
# #### unnesting columns

# %%
casts = df["cast"].apply(lambda x:str(x).split(", ")).tolist()
casts = pd.DataFrame(casts,index=df["title"])
casts = casts.stack()
casts = pd.DataFrame(casts).reset_index()
casts = casts[["title",0]]
casts.columns = ["title","cast"]

directors = df["director"].apply(lambda x:str(x).split(", ")).tolist()
directors = pd.DataFrame(directors,index=df["title"])
directors = directors.stack()
directors = pd.DataFrame(directors).reset_index()
directors = directors[["title",0]]
directors.columns = ["title","directors"]

countries = df["country"].apply(lambda x:str(x).split(", ")).tolist()
countries = pd.DataFrame(countries,index=df["title"])
countries = countries.stack()
countries = pd.DataFrame(countries).reset_index()
countries = countries[["title",0]]
countries.columns = ["title","countries"]

genres = df["listed_in"].apply(lambda x:str(x).split(", ")).tolist()
genres = pd.DataFrame(genres,index=df["title"])
genres = genres.stack()
genres = pd.DataFrame(genres).reset_index()
genres = genres[["title",0]]
genres.columns = ["title","genres"]

# %% [markdown]
# #### Merging unnested data with original data frame :

# %%
data = pd.merge(pd.merge(pd.merge(pd.merge(casts,directors,on="title"),countries,on="title"),genres,on="title"),df,on="title")

# %%
data.columns
# Out:
# Index(['title', 'cast_x', 'directors', 'countries', 'genres', 'show_id',
#        'type', 'director', 'cast_y', 'country', 'date_added', 'release_year',
#        'rating', 'listed_in', 'serial_no', 'year_added', 'month_added',
#        'Movie_duration', 'Series_duration', 'Content_For'],
#       dtype='object')

# %%
data.duplicated().value_counts()
# Out:
# False    201936
# True         55
# dtype: int64

# %%
201936+55
# Out:
# 201991

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201991 entries, 0 to 201990
# Data columns (total 20 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   title            201991 non-null  object
#  1   cast_x           201991 non-null  object
#  2   directors        201991 non-null  object
#  3   countries        201991 non-null  object
#  4   genres           201991 non-null  object
#  5   show_id          201991 non-null  object
#  6   type             201991 non-null  object
#  7   director         201991 non-null  object
#  8   cast_y           201991 non-null  object
#  9   country          201991 non-null  object
#  10  date_added       201833 non-null  datetime64[ns]
#  11  release_year     201991 non-null  int64
#  12  rating           201924 non-null  object
#  13  listed_in        201991 non-null  object
#  14  serial_no        201991 non-null  int64
#  15  year_added       201833 non-null  float64
#  16  month_added      201833 non-null  object
#  17  Movie_duration   145840 non-null  float64
#  18  Series_duration  56148 non-null   float64
#  19  Content_For      201924 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(14)
# memory usage: 32.4+ MB

# %%
data.shape
# Out:
# (201991, 20)

# %% [markdown]
# ##### dropping unncessary old nested data

# %%
data.drop(["cast_y","director","country","listed_in"],axis = 1,inplace=True)

# %%
data.rename({"cast_x":"actors"},axis = 1,inplace=True)

# %%
data.head(5)
# Out:
#                   title       actors        directors      countries  \
# 0  Dick Johnson Is Dead      Unknown  Kirsten Johnson  United States
# 1         Blood & Water   Ama Qamata          Unknown   South Africa
# 2         Blood & Water   Ama Qamata          Unknown   South Africa
# 3         Blood & Water   Ama Qamata          Unknown   South Africa
# 4         Blood & Water  Khosi Ngema          Unknown   South Africa
#
#                    genres show_id     type date_added  release_year rating  \
# 0           Documentaries      s1    Movie 2021-09-25          2020  PG-13
# 1  International TV Shows      s2  TV Show 2021-09-24          2021  TV-MA
# 2               TV Dramas      s2  TV Show 2021-09-24          2021  TV-MA
# 3            TV Mysteries      s2  TV Show 2021-09-24          2021  TV-MA
# 4  International TV Shows      s2  TV Show 2021-09-24          2021  TV-MA
#
#    serial_no  year_added month_added  Movie_duration  Series_duration  \
# 0          0      2021.0   September            90.0              NaN
# 1          1      2021.0   September             NaN              2.0
# 2          1      2021.0   September             NaN              2.0
# 3          1      2021.0   September             NaN              2.0
# 4          1      2021.0   September             NaN              2.0
#
#   Content_For
# 0       Teens
# 1      Adults
# 2      Adults
# 3      Adults
# 4      Adults

# %%
data.shape
# Out:
# (201991, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201991 entries, 0 to 201990
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   title            201991 non-null  object
#  1   actors           201991 non-null  object
#  2   directors        201991 non-null  object
#  3   countries        201991 non-null  object
#  4   genres           201991 non-null  object
#  5   show_id          201991 non-null  object
#  6   type             201991 non-null  object
#  7   date_added       201833 non-null  datetime64[ns]
#  8   release_year     201991 non-null  int64
#  9   rating           201924 non-null  object
#  10  serial_no        201991 non-null  int64
#  11  year_added       201833 non-null  float64
#  12  month_added      201833 non-null  object
#  13  Movie_duration   145840 non-null  float64
#  14  Series_duration  56148 non-null   float64
#  15  Content_For      201924 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(10)
# memory usage: 26.2+ MB

# %% [markdown]
# ## Analysing Genres  { Content which are listed in: }

# %%
totalcontent_in_all_genres = data.groupby("genres")["title"].nunique().sum()

# %%
totalcontent_in_all_genres
# Out:
# 19323

# %%
((data.groupby("genres")["title"].nunique().sort_values(ascending=False)/totalcontent_in_all_genres)*100).head(23).sum()
# Out:
# 91.06763960047611

# %%
genres_wise_distribution = ((data.groupby("genres")["title"].nunique().sort_values(ascending=False)/totalcontent_in_all_genres)*100)
genres_wise_distribution
# Out:
# genres
# International Movies            14.242095
# Dramas                          12.560161
# Comedies                         8.663251
# International TV Shows           6.991668
# Documentaries                    4.497231
# Action & Adventure               4.445479
# TV Dramas                        3.948662
# Independent Movies               3.912436
# Children & Family Movies         3.317290
# Romantic Movies                  3.187911
# TV Comedies                      3.006779
# Thrillers                        2.986079
# Crime TV Shows                   2.432335
# Kids' TV                         2.334006
# Docuseries                       2.044196
# Music & Musicals                 1.940692
# Romantic TV Shows                1.914817
# Horror Movies                    1.847539
# Stand-Up Comedy                  1.775087
# Reality TV                       1.319671
# British TV Shows                 1.309320
# Sci-Fi & Fantasy                 1.257569
# Sports Movies                    1.133364
# Anime Series                     0.910832
# Spanish-Language TV Shows        0.900481
# TV Action & Adventure            0.869430
# Korean TV Shows                  0.781452
# Classic Movies                   0.600321
# LGBTQ Movies                     0.527868
# TV Mysteries                     0.507168
# Science & Nature TV              0.476117
# TV Sci-Fi & Fantasy              0.434715
# TV Horror                        0.388138
# Anime Features                   0.367438
# Cult Movies                      0.367438
# Teen TV Shows                    0.357087
# Faith & Spirituality             0.336387
# TV Thrillers                     0.294985
# Movies                           0.294985
# Stand-Up Comedy & Talk Shows     0.289810
# Classic & Cult TV                0.144905
# TV Shows                         0.082803
# Name: title, dtype: float64

# %% [markdown]
# ##### Total 25 different Genres with their Movie Counts :

# %%
data.groupby("genres")["title"].nunique().sort_values(ascending=False).head(25).reset_index()
# Out:
#                        genres  title
# 0        International Movies   2752
# 1                      Dramas   2427
# 2                    Comedies   1674
# 3      International TV Shows   1351
# 4               Documentaries    869
# 5          Action & Adventure    859
# 6                   TV Dramas    763
# 7          Independent Movies    756
# 8    Children & Family Movies    641
# 9             Romantic Movies    616
# 10                TV Comedies    581
# 11                  Thrillers    577
# 12             Crime TV Shows    470
# 13                   Kids' TV    451
# 14                 Docuseries    395
# 15           Music & Musicals    375
# 16          Romantic TV Shows    370
# 17              Horror Movies    357
# 18            Stand-Up Comedy    343
# 19                 Reality TV    255
# 20           British TV Shows    253
# 21           Sci-Fi & Fantasy    243
# 22              Sports Movies    219
# 23               Anime Series    176
# 24  Spanish-Language TV Shows    174

# %% [markdown]
# ##### Genre distribution across the world :

# %%
genredist  = data.groupby("genres")["title"].nunique().sort_values(ascending=False).head(25).reset_index()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = "genres" , y="title" , data = genredist )
plt.title("Content as per genre")
plt.xlabel("genres")
plt.ylabel("% of content per genre")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### most popular genres on netflix are:

# %%
most_popular_genres = genres_wise_distribution.head(20).index
most_popular_genres
# Out:
# Index(['International Movies', 'Dramas', 'Comedies', 'International TV Shows',
#        'Documentaries', 'Action & Adventure', 'TV Dramas',
#        'Independent Movies', 'Children & Family Movies', 'Romantic Movies',
#        'TV Comedies', 'Thrillers', 'Crime TV Shows', 'Kids' TV', 'Docuseries',
#        'Music & Musicals', 'Romantic TV Shows', 'Horror Movies',
#        'Stand-Up Comedy', 'Reality TV'],
#       dtype='object', name='genres')

# %% [markdown]
# # `GLOBAL INSIGHTS `

# %%
data.head()
# Out:
#                   title       actors        directors      countries  \
# 0  Dick Johnson Is Dead      Unknown  Kirsten Johnson  United States
# 1         Blood & Water   Ama Qamata          Unknown   South Africa
# 2         Blood & Water   Ama Qamata          Unknown   South Africa
# 3         Blood & Water   Ama Qamata          Unknown   South Africa
# 4         Blood & Water  Khosi Ngema          Unknown   South Africa
#
#                    genres show_id     type date_added  release_year rating  \
# 0           Documentaries      s1    Movie 2021-09-25          2020  PG-13
# 1  International TV Shows      s2  TV Show 2021-09-24          2021  TV-MA
# 2               TV Dramas      s2  TV Show 2021-09-24          2021  TV-MA
# 3            TV Mysteries      s2  TV Show 2021-09-24          2021  TV-MA
# 4  International TV Shows      s2  TV Show 2021-09-24          2021  TV-MA
#
#    serial_no  year_added month_added  Movie_duration  Series_duration  \
# 0          0      2021.0   September            90.0              NaN
# 1          1      2021.0   September             NaN              2.0
# 2          1      2021.0   September             NaN              2.0
# 3          1      2021.0   September             NaN              2.0
# 4          1      2021.0   September             NaN              2.0
#
#   Content_For
# 0       Teens
# 1      Adults
# 2      Adults
# 3      Adults
# 4      Adults

# %% [markdown]
# ## Most Frequent Actors from the dataset :

# %% [markdown]
# #### top 50 actors : their maximum number of content they have worked on and countires they have worked in .

# %%
data.groupby("actors")[["title","countries"]].aggregate({"title":"nunique",
                                                        "countries":"nunique"}).sort_values(by="title",ascending=False).head(50)
# Out:
#                      title  countries
# actors
# Unknown                825         65
# Anupam Kher             43          5
# Shah Rukh Khan          35          5
# Julie Tejwani           33          2
# Naseeruddin Shah        32          4
# Takahiro Sakurai        32          2
# Rupa Bhimani            31          2
# Om Puri                 30          6
# Akshay Kumar            30          2
# Yuki Kaji               29          2
# Paresh Rawal            28          3
# Amitabh Bachchan        28          1
# Boman Irani             27          4
# Vincent Tong            26         13
# Rajesh Kava             26          2
# Andrea Libman           25          6
# Kareena Kapoor          25          2
# Samuel L. Jackson       24          7
# John Cleese             24         13
# Tara Strong             23          9
# Fred Tatasciore         23          5
# Jigna Bhardwaj          23          2
# Daisuke Ono             22          1
# Kay Kay Menon           21          3
# Nawazuddin Siddiqui     21          4
# Ashleigh Ball           21          7
# Ajay Devgn              21          2
# Nicolas Cage            21          7
# Junichi Suwabe          21          2
# Salman Khan             20          1
# Adam Sandler            20          1
# David Attenborough      20          7
# Fred Armisen            19          6
# David Spade             19          3
# Ai Kayano               19          2
# Yuichi Nakamura         19          2
# James Franco            19         13
# Seth Rogen              19          4
# Erin Fitzgerald         19          6
# Gulshan Grover          19          4
# Mamoru Miyano           19          2
# Morgan Freeman          19          6
# Diana Kaarina           18          3
# Rajesh Sharma           18          2
# Vatsal Dubey            18          2
# Kana Hanazawa           18          1
# Yashpal Sharma          18          4
# Debi Derryberry         18          8
# Anil Kapoor             18          2
# Laura Bailey            18          2

# %% [markdown]
# #### top 20 directors  : their number of content and the counties they have worked in .

# %%
data.groupby("directors")[["title","countries"]].aggregate({"title":"nunique",
                                                        "countries":"nunique"}).sort_values(by="title",ascending=False).head(20)
# Out:
#                      title  countries
# directors
# Unknown               2634         67
# Rajiv Chilaka           22          2
# Jan Suter               21          4
# Raúl Campos             19          4
# Marcus Raboy            16          2
# Suhas Kadav             16          2
# Jay Karas               15          1
# Cathy Garcia-Molina     13          1
# Jay Chapman             12          1
# Martin Scorsese         12          6
# Youssef Chahine         12          3
# Steven Spielberg        11          5
# Don Michael Paul        10          4
# Yılmaz Erdoğan           9          1
# Anurag Kashyap           9          2
# Shannon Hartman          9          1
# David Dhawan             9          1
# Justin G. Dyck           8          2
# Hanung Bramantyo         8          2
# Hakan Algül              8          1

# %% [markdown]
# ## number of Content per Country on Netflix

# %%
# df["country"].value_counts(dropna=False).head(20)

movies_per_country  = data.groupby("countries")["title"].nunique().sort_values(ascending=False).head(20)
movies_per_country
# Out:
# countries
# United States     3689
# India             1046
# Unknown            831
# United Kingdom     804
# Canada             445
# France             393
# Japan              318
# Spain              232
# South Korea        231
# Germany            226
# Mexico             169
# China              162
# Australia          160
# Egypt              117
# Turkey             113
# Hong Kong          105
# Nigeria            103
# Italy              100
# Brazil              97
# Argentina           91
# Name: title, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.bar(movies_per_country.index,height=movies_per_country)

plt.xlabel("Countires")
plt.ylabel("# Content per Country")

# plt.xticks(20)
plt.xticks(rotation = 90)


plt.show()

# %%
(data.groupby("countries")["title"].nunique().sort_values(ascending=False).head(20).sum()/10845)*100
# Out:
# 86.97095435684648

# %% [markdown]
# 87 % of the Contents is from above 20 Countries.

# %%
# business in top 10 countires
top_20_countires = movies_per_country.index

# %%
top_20_countires
# Out:
# Index(['United States', 'India', 'Unknown', 'United Kingdom', 'Canada',
#        'France', 'Japan', 'Spain', 'South Korea', 'Germany', 'Mexico', 'China',
#        'Australia', 'Egypt', 'Turkey', 'Hong Kong', 'Nigeria', 'Italy',
#        'Brazil', 'Argentina'],
#       dtype='object', name='countries')

# %% [markdown]
# ### # Number of content added per year

# %%
# mvies added per year

plt.figure(figsize=(10,5))
sns.barplot(y = data.groupby(data["date_added"].dt.year)["title"].nunique().sort_values(ascending=False),
            x =data.groupby(data["date_added"].dt.year)["title"].nunique().sort_values(ascending=False).index )
plt.xticks(rotation = 90)
plt.xlabel("years")
plt.ylabel("number of movies")
plt.show()

# %% [markdown]
# ### top actors per perticular genre :(Internationally)

# %%
most_popular_genres
# Out:
# Index(['International Movies', 'Dramas', 'Comedies', 'International TV Shows',
#        'Documentaries', 'Action & Adventure', 'TV Dramas',
#        'Independent Movies', 'Children & Family Movies', 'Romantic Movies',
#        'TV Comedies', 'Thrillers', 'Crime TV Shows', 'Kids' TV', 'Docuseries',
#        'Music & Musicals', 'Romantic TV Shows', 'Horror Movies',
#        'Stand-Up Comedy', 'Reality TV'],
#       dtype='object', name='genres')

# %%
for genre in most_popular_genres:
    print()
    print(genre)
    print("== Actor ======= number of movies =")
    print(data[data["genres"]==genre].groupby("actors")["title"].nunique().sort_values(ascending=False).head(10))
    print()
# Out:
# International Movies
# == Actor ======= number of movies =
# actors
# Unknown             178
# Anupam Kher          38
# Shah Rukh Khan       32
# Om Puri              27
# Akshay Kumar         27
# Naseeruddin Shah     27
# Boman Irani          25
# Kareena Kapoor       25
# Paresh Rawal         25
# Amitabh Bachchan     23
# Name: title, dtype: int64
#
#
# Dramas
# == Actor ======= number of movies =
# actors
# Anupam Kher            28
# Shah Rukh Khan         28
# Naseeruddin Shah       28
# Amitabh Bachchan       20
# Om Puri                20
# Nawazuddin Siddiqui    18
# Paresh Rawal           18
# Kay Kay Menon          17
# Akshay Kumar           16
# Kareena Kapoor         15
# Name: title, dtype: int64
#
#
# Comedies
# == Actor ======= number of movies =
# actors
# Anupam Kher         20
# Paresh Rawal        18
# Adam Sandler        18
# Akshay Kumar        15
# Shah Rukh Khan      15
# Hassan Hosny        15
# Boman Irani         15
# David Spade         14
# Maya Rudolph        14
# Naseeruddin Shah    13
# Name: title, dtype: int64
#
#
# International TV Shows
# == Actor ======= number of movies =
# actors
# Unknown             109
# Takahiro Sakurai     22
# Yuki Kaji            18
# Junichi Suwabe       16
# Ai Kayano            16
# Yoshimasa Hosoya     14
# Daisuke Ono          14
# Yuichi Nakamura      13
# Jun Fukuyama         13
# Takehito Koyasu      13
# Name: title, dtype: int64
#
#
# Documentaries
# == Actor ======= number of movies =
# actors
# Unknown           424
# Samuel West        10
# Craig Sechler       6
# Wille Lindberg      5
# Quincy Jones        5
# Terry Jones         4
# Terry Gilliam       4
# Jesse Richman       4
# Eric Idle           4
# Graham Chapman      4
# Name: title, dtype: int64
#
#
# Action & Adventure
# == Actor ======= number of movies =
# actors
# Bruce Willis         13
# Amitabh Bachchan     12
# Anupam Kher          12
# Shah Rukh Khan       11
# Samuel L. Jackson    10
# Jackie Shroff        10
# Jackie Chan          10
# Nicolas Cage         10
# Donnie Yen           10
# Boman Irani           9
# Name: title, dtype: int64
#
#
# TV Dramas
# == Actor ======= number of movies =
# actors
# Tay Ping Hui       10
# Jeanette Aw         7
# Zhang Zhenhuan      7
# Unknown             6
# Christopher Lee     6
# Mike Colter         5
# Yao Wenlong         5
# Elvin Ng            5
# Rui En              5
# Frederick Lee       5
# Name: title, dtype: int64
#
#
# Independent Movies
# == Actor ======= number of movies =
# actors
# Naseeruddin Shah         10
# Rajit Kapoor              8
# Mark Duplass              7
# Konkona Sen Sharma        7
# Tannishtha Chatterjee     7
# Adil Hussain              7
# John C. Reilly            6
# Kishore Kadam             6
# Matthew Gray Gubler       5
# Alia Shawkat              5
# Name: title, dtype: int64
#
#
# Children & Family Movies
# == Actor ======= number of movies =
# actors
# Unknown            33
# Julie Tejwani      26
# Rupa Bhimani       25
# Rajesh Kava        21
# Jigna Bhardwaj     19
# Vatsal Dubey       16
# Andrea Libman      15
# Laura Bailey       14
# Tara Strong        14
# Erin Fitzgerald    13
# Name: title, dtype: int64
#
#
# Romantic Movies
# == Actor ======= number of movies =
# actors
# Akshay Kumar        8
# Salman Khan         7
# Anupam Kher         7
# Shah Rukh Khan      7
# Unknown             7
# Robert Pattinson    6
# Taylor Lautner      6
# Kristen Stewart     6
# Peter Facinelli     6
# Kareena Kapoor      6
# Name: title, dtype: int64
#
#
# TV Comedies
# == Actor ======= number of movies =
# actors
# Unknown                     24
# Tony Hale                    5
# Grey Griffin                 5
# Fortune Feimster             5
# James Wen                    5
# Kevin Michael Richardson     4
# Matt Hill                    4
# Ken Marino                   4
# Tia Lee                      4
# Nat Faxon                    4
# Name: title, dtype: int64
#
#
# Thrillers
# == Actor ======= number of movies =
# actors
# Nicolas Cage            7
# Nawazuddin Siddiqui     7
# Ben Kingsley            7
# Nana Patekar            6
# John Abraham            6
# Jennifer Jason Leigh    6
# Ajay Devgn              5
# Jake Gyllenhaal         5
# Rajesh Sharma           5
# Brian Cox               5
# Name: title, dtype: int64
#
#
# Crime TV Shows
# == Actor ======= number of movies =
# actors
# Unknown                75
# Eréndira Ibarra         4
# Juan Pablo Urrego       4
# Alejandro Speitzer      4
# Mike Colter             4
# Damián Alcázar          4
# Yuki Kaji               4
# Luis Roberto Guzmán     4
# Diego Cadavid           4
# Diego Vásquez           4
# Name: title, dtype: int64
#
#
# Kids' TV
# == Actor ======= number of movies =
# actors
# Unknown           42
# Vincent Tong      13
# Ashleigh Ball     11
# Grey Griffin       9
# Michela Luci       9
# Tara Strong        8
# Andrea Libman      8
# Brian Drummond     8
# Kathleen Barr      8
# Sam Vincent        8
# Name: title, dtype: int64
#
#
# Docuseries
# == Actor ======= number of movies =
# actors
# Unknown               207
# David Attenborough     14
# David Chang             3
# Morgan Freeman          3
# Liz Bonnin              2
# Eric Idle               2
# R. Kelly                2
# Erik Thompson           2
# Nicholas Day            2
# Anitta                  2
# Name: title, dtype: int64
#
#
# Music & Musicals
# == Actor ======= number of movies =
# actors
# Unknown               35
# Gulshan Grover         7
# Anil Kapoor            7
# Akshay Kumar           7
# Kareena Kapoor         6
# Katrina Kaif           6
# Amrish Puri            6
# Anupam Kher            5
# Saurav Chakraborty     5
# Alok Nath              5
# Name: title, dtype: int64
#
#
# Romantic TV Shows
# == Actor ======= number of movies =
# actors
# Unknown        13
# Amanda Chou     6
# Jack Lee        5
# Patrick Lee     5
# Chris Wang      5
# James Wen       5
# Tia Lee         4
# Lee Il-hwa      4
# Joe Chen        4
# Ivy Shao        4
# Name: title, dtype: int64
#
#
# Horror Movies
# == Actor ======= number of movies =
# actors
# Michael Gross         7
# Tony Todd             5
# Jamie Kennedy         4
# Lucy Boynton          4
# Ali Larter            4
# Surya Ganapathy       4
# Pavel Navageethan     4
# Javier Botet          4
# Doug Jones            4
# Avantika Vandanapu    4
# Name: title, dtype: int64
#
#
# Stand-Up Comedy
# == Actor ======= number of movies =
# actors
# Jeff Dunham         8
# Kevin Hart          8
# Katt Williams       6
# Tom Segura          5
# Iliza Shlesinger    5
# Bill Burr           5
# Jim Jefferies       5
# Jim Gaffigan        5
# John Mulaney        5
# Vir Das             5
# Name: title, dtype: int64
#
#
# Reality TV
# == Actor ======= number of movies =
# actors
# Unknown           92
# Yoshimi Tokui      4
# Rutledge Wood      4
# Ryota Yamasato     4
# Azusa Babazono     4
# Paul Hollywood     4
# You                4
# Reina Triendl      4
# Nadiya Hussain     3
# Tan France         3
# Name: title, dtype: int64

# %% [markdown]
# ### top Directors per perticular genre :(Internationally)

# %%
for genre in most_popular_genres:
    print()
    print(genre)
    print("== Directors ======= number of movies =")
    print(data[data["genres"]==genre].groupby("directors")["title"].nunique().sort_values(ascending=False).head(10))
    print()
# Out:
# International Movies
# == Directors ======= number of movies =
# directors
# Unknown                47
# Cathy Garcia-Molina    13
# Youssef Chahine        10
# Yılmaz Erdoğan          9
# Hanung Bramantyo        8
# Johnnie To              8
# Anurag Kashyap          8
# David Dhawan            8
# Umesh Mehra             8
# Hakan Algül             8
# Name: title, dtype: int64
#
#
# Dramas
# == Directors ======= number of movies =
# directors
# Unknown                25
# Youssef Chahine        12
# Martin Scorsese         9
# Cathy Garcia-Molina     9
# Hanung Bramantyo        8
# Hidenori Inoue          7
# S.S. Rajamouli          7
# Clint Eastwood          6
# Sooraj R. Barjatya      6
# Yılmaz Erdoğan          6
# Name: title, dtype: int64
#
#
# Comedies
# == Directors ======= number of movies =
# directors
# Unknown                32
# David Dhawan            9
# Suhas Kadav             8
# Hakan Algül             8
# Prakash Satam           7
# Cathy Garcia-Molina     7
# Robert Rodriguez        6
# Yılmaz Erdoğan          6
# Fernando Ayllón         6
# Wenn V. Deramas         6
# Name: title, dtype: int64
#
#
# International TV Shows
# == Directors ======= number of movies =
# directors
# Unknown                    1223
# Alastair Fothergill           3
# Jung-ah Im                    2
# Hsu Fu-chun                   2
# Shin Won-ho                   2
# Abhishek Chaubey              1
# Nopparoj Chotmunkongsit       1
# Obi Emelonye                  1
# Olivier Megaton               1
# Onur Ünlü                     1
# Name: title, dtype: int64
#
#
# Documentaries
# == Directors ======= number of movies =
# directors
# Unknown             57
# Vlad Yudin           6
# Thierry Donard       5
# Barry Avrich         4
# Hernán Zin           4
# Matt Askem           4
# Edward Cotterill     4
# Frank Capra          4
# John Huston          4
# Luis Ara             4
# Name: title, dtype: int64
#
#
# Action & Adventure
# == Directors ======= number of movies =
# directors
# Don Michael Paul     9
# Unknown              8
# S.S. Rajamouli       7
# Hidenori Inoue       7
# Toshiya Shinohara    7
# Steven Spielberg     5
# Ram Gopal Varma      5
# Lilly Wachowski      5
# Masahiko Murata      5
# Martin Campbell      5
# Name: title, dtype: int64
#
#
# TV Dramas
# == Directors ======= number of movies =
# directors
# Unknown                702
# Abhishek Chaubey         1
# Pass Patthanakumjon      1
# Serdar Akar              1
# Sankalp Reddy            1
# Rob Seidenglanz          1
# Quek Shio-chuan          1
# Philippa Lowthorpe       1
# Peter Ho                 1
# Pavel Kostomarov         1
# Name: title, dtype: int64
#
#
# Independent Movies
# == Directors ======= number of movies =
# directors
# Noah Baumbach           5
# Paul Thomas Anderson    5
# Unknown                 5
# Qaushiq Mukherjee       4
# Alfonso Cuarón          3
# Lynn Shelton            3
# Onir                    3
# Antonio Campos          3
# Jeff Baena              3
# Julián Hernández        2
# Name: title, dtype: int64
#
#
# Children & Family Movies
# == Directors ======= number of movies =
# directors
# Unknown             36
# Rajiv Chilaka       22
# Suhas Kadav         16
# Prakash Satam        7
# Robert Rodriguez     7
# Tilak Shetty         6
# Steven Spielberg     6
# William Lau          6
# Robert Vince         6
# Joey So              6
# Name: title, dtype: int64
#
#
# Romantic Movies
# == Directors ======= number of movies =
# directors
# Unknown                11
# Cathy Garcia-Molina     8
# Justin G. Dyck          6
# Antoinette Jadaone      4
# Imtiaz Ali              4
# Fajar Bustomi           4
# Hakan Algül             4
# Mae Czarina Cruz        4
# Robert Luketic          4
# Roger Kumble            4
# Name: title, dtype: int64
#
#
# TV Comedies
# == Directors ======= number of movies =
# directors
# Unknown              539
# Stan Lathan            2
# Aco Tenriyagelli       1
# Ousmane Ly             1
# Kongkiat Khomsiri      1
# Lars Kaalund           1
# Malik Nejer            1
# Marcus Raboy           1
# Michael Cumming        1
# Mike Smith             1
# Name: title, dtype: int64
#
#
# Thrillers
# == Directors ======= number of movies =
# directors
# David Fincher               4
# Rathindran R Prasad         4
# Ashwin Saravanan            3
# Fernando González Molina    3
# Kunle Afolayan              3
# Anurag Kashyap              3
# Mike Flanagan               3
# Gregory Hoblit              3
# Brad Anderson               3
# Chris Sivertson             2
# Name: title, dtype: int64
#
#
# Crime TV Shows
# == Directors ======= number of movies =
# directors
# Unknown              401
# Ahmet Katıksız         1
# Mauricio Dias          1
# Pantham Thongsang      1
# Oriol Paulo            1
# Olivier Megaton        1
# Nicolas Lopez          1
# Miguel Conde           1
# Mick Grogan            1
# Michael Samuels        1
# Name: title, dtype: int64
#
#
# Kids' TV
# == Directors ======= number of movies =
# directors
# Unknown               433
# Iginio Straffi          2
# Ah Loong                1
# Kenny Ortega            1
# Vijay Roche             1
# Tony Collingwood        1
# Thomas Astruc           1
# Stephen Murray          1
# Olivier Jean-Marie      1
# Kyran Kelly             1
# Name: title, dtype: int64
#
#
# Docuseries
# == Directors ======= number of movies =
# directors
# Unknown                335
# Alastair Fothergill      3
# Ken Burns                3
# Lynn Novick              2
# Mark Lewis               1
# Padraic McKinley         1
# Olivier Megaton          1
# Oliver Stone             1
# Moyoung Jin              1
# Mick Grogan              1
# Name: title, dtype: int64
#
#
# Music & Musicals
# == Directors ======= number of movies =
# directors
# Unknown                      17
# Matt Askem                    6
# Suhas Kadav                   5
# Lucas Margutti                4
# Detlev Buck                   4
# Paul Dugdale                  4
# David Dhawan                  3
# Mastan Alibhai Burmawalla     3
# B. V. Nandini Reddy           3
# Sooraj R. Barjatya            3
# Name: title, dtype: int64
#
#
# Romantic TV Shows
# == Directors ======= number of movies =
# directors
# Unknown                 341
# Shin Won-ho               2
# Hsu Fu-chun               2
# Kongkiat Khomsiri         1
# Takuya Igarashi           1
# Sarawut Wichiensarn       1
# Sakon Tiacharoen          1
# Richard Arellano          1
# Rachit Kusonkoonsiri      1
# Park Joon-hwa             1
# Name: title, dtype: int64
#
#
# Horror Movies
# == Directors ======= number of movies =
# directors
# Rocky Soraya             6
# Poj Arnon                5
# Rathindran R Prasad      4
# Leigh Janiak             3
# Scott Stewart            3
# Banjong Pisanthanakun    3
# Don Michael Paul         3
# Kevin Smith              3
# Hasan Karacadağ          3
# Ashwin Saravanan         3
# Name: title, dtype: int64
#
#
# Stand-Up Comedy
# == Directors ======= number of movies =
# directors
# Unknown            25
# Jan Suter          21
# Raúl Campos        19
# Marcus Raboy       15
# Jay Karas          14
# Jay Chapman        12
# Shannon Hartman     9
# Lance Bangs         8
# Troy Miller         7
# Ryan Polito         7
# Name: title, dtype: int64
#
#
# Reality TV
# == Directors ======= number of movies =
# directors
# Unknown                   249
# Adrián García Bogliano      1
# Andy Devonshire             1
# Bumpy                       1
# Carla Barros                1
# Cassia Dian                 1
# Michael Simon               1
# Name: title, dtype: int64

# %% [markdown]
# # people who have worked in multiple countires and who have their audiance around the globe.

# %%
## top 10 directors who have content in maximum number of countires

# %%
data.groupby("directors")["countries"].nunique().sort_values(ascending =False).head(10)
# Out:
# directors
# Unknown               67
# Matthew Salleh        12
# Joshua Oppenheimer    10
# Farhad Safinia         8
# Martin Campbell        8
# James Watkins          7
# Aaron Woodley          7
# Renny Harlin           7
# Nora Twomey            7
# Brian De Palma         7
# Name: countries, dtype: int64

# %%
## top 10 actors who have content in maximum number of countires

# %%
data.groupby("actors")["countries"].nunique().sort_values(ascending =False).head(10)
# Out:
# actors
# Unknown               65
# Alfred Molina         14
# Paul Giamatti         14
# Mads Mikkelsen        13
# Ben Whishaw           13
# James Franco          13
# Eddie Marsan          13
# Vincent Tong          13
# Sylvester Stallone    13
# John Cleese           13
# Name: countries, dtype: int64

# %%
# possible content of these people is watched all over in the world we can say!

# %% [markdown]
# # Top 20 Versatile Actors who have worked in various types of movies:
#
# #### also their movie counts in the title column

# %%
data.columns
# Out:
# Index(['title', 'actors', 'directors', 'countries', 'genres', 'show_id',
#        'type', 'date_added', 'release_year', 'rating', 'serial_no',
#        'year_added', 'month_added', 'Movie_duration', 'Series_duration',
#        'Content_For'],
#       dtype='object')

# %%
data.groupby("actors")["genres","title"].aggregate({
    "genres":"nunique",
    "title":"nunique"
}).sort_values(by = ["genres","title"],ascending=[False,False]).head(20)[1:]
# Out:
#                     genres  title
# actors
# Ron Perlman             17     13
# Gary Cole               16     11
# Kiernan Shipka          16      9
# Glenn Close             15     12
# Anupam Kher             14     43
# Samuel L. Jackson       14     24
# Rajesh Sharma           14     18
# Antonio Banderas        14     15
# Ben Kingsley            14     15
# Keith David             14     15
# Guy Pearce              14     14
# Jim Broadbent           14     13
# John Leguizamo          14     12
# Carla Gugino            14     11
# Jay Baruchel            14     11
# Keegan-Michael Key      14     11
# Mae Whitman             14      9
# Rosamund Pike           14      9
# Nicholas Hoult          14      8

# %% [markdown]
# # Top 20 Versatile Directors who have worked in various types of movies:
#
# ### also their movie counts in the title column

# %%
data.groupby("directors")["genres","title"].aggregate({
    "genres":"nunique",
    "title":"nunique"
}).sort_values(by = ["genres","title"],ascending=[False,False]).head(20)[1:]
# Out:
#                       genres  title
# directors
# Martin Scorsese            9     12
# Anurag Kashyap             9      9
# Priyadarshan               8      7
# Abhishek Chaubey           8      5
# Vishal Bhardwaj            8      5
# Vikramaditya Motwane       8      4
# Ifa Isfansyah              8      3
# David Dhawan               7      9
# Clint Eastwood             7      7
# Ron Howard                 7      7
# Brad Anderson              7      4
# Jeremy Saulnier            7      4
# BB Sasore                  7      3
# Guillermo del Toro         7      3
# Jalil Lespert              7      3
# Julien Leclercq            7      3
# Manolo Caro                7      3
# Tim Burton                 7      3
# Youssef Chahine            6     12

# %% [markdown]
# # Number of movie and series produced per year

# %%
movies_series_per_year_counts = df.groupby("year_added")["Movie_duration","Series_duration"].aggregate({
    "Movie_duration":"count",
    "Series_duration":"count"
}).reset_index()

# %%
movies_series_per_year_counts.rename(columns={"Movie_duration":"Movie Count","Series_duration":"Series Count"},inplace=True)
movies_series_per_year_counts
# Out:
#     year_added  Movie Count  Series Count
# 0       2008.0            1             1
# 1       2009.0            2             0
# 2       2010.0            1             0
# 3       2011.0           13             0
# 4       2012.0            3             0
# 5       2013.0            6             5
# 6       2014.0           19             5
# 7       2015.0           56            26
# 8       2016.0          251           176
# 9       2017.0          838           349
# 10      2018.0         1237           412
# 11      2019.0         1424           592
# 12      2020.0         1284           595
# 13      2021.0          993           505

# %% [markdown]
# # change in duration of movies and series over the years

# %%
data.groupby("year_added")["Movie_duration"].mean()
# Out:
# year_added
# 2008.0     81.000000
# 2009.0     89.000000
# 2010.0     84.000000
# 2011.0     83.746575
# 2012.0     54.555556
# 2013.0    105.986667
# 2014.0     83.903790
# 2015.0     91.312000
# 2016.0     98.068575
# 2017.0    105.126349
# 2018.0    109.552248
# 2019.0    106.754108
# 2020.0    107.158986
# 2021.0    108.072010
# Name: Movie_duration, dtype: float64

# %%
data.groupby("year_added")["Series_duration"].mean()
# Out:
# year_added
# 2008.0    1.000000
# 2009.0         NaN
# 2010.0         NaN
# 2011.0         NaN
# 2012.0         NaN
# 2013.0    3.833333
# 2014.0    4.028037
# 2015.0    3.149425
# 2016.0    1.403934
# 2017.0    1.855397
# 2018.0    1.865676
# 2019.0    1.698579
# 2020.0    2.130502
# 2021.0    2.064296
# Name: Series_duration, dtype: float64

# %% [markdown]
# ### Trend around how the movie/series length as increased over the years.

# %%
plt.figure(figsize=(5,10))

# sns.boxplot(x = data["Movie_duration"] )
sns.lineplot(x = data.groupby("year_added")["Movie_duration"].mean().index,
             y = data.groupby("year_added")["Movie_duration"].mean())
sns.lineplot(x = data.groupby("year_added")["Series_duration"].mean().index,
             y = data.groupby("year_added")["Series_duration"].mean())

plt.ylabel("TV Show Duration & Movie Duration Trend Line")
plt.legend(["Movies Duration","TV series Duration"])

# %% [markdown]
# ##### in above first plot(left one) shows , how movie duration(blue line) trend has changed during last few years . which is average of mean duration for each year.
# ##### and Orange line which shows the mean average time for tv shows(series duration) .

# %% [markdown]
# ### Duration of Movies and Series : distribution plot

# %%
plt.figure(figsize=(8,5))
Movie_duration = data.groupby("title")["Movie_duration"].value_counts()
Movie_duration = pd.DataFrame(Movie_duration)
Movie_duration.rename({"Movie_duration":"duration"},axis = 1,inplace=True)
Movie_duration.reset_index()["Movie_duration"]
sns.distplot(Movie_duration.reset_index()["Movie_duration"],bins = 40)
# Out:
# <AxesSubplot:xlabel='Movie_duration', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
Series_duration = data.groupby("title")["Series_duration"].value_counts()
Series_duration = pd.DataFrame(Series_duration)
Series_duration.rename({"Series_duration":"duration"},axis = 1,inplace=True)
Series_duration.reset_index()["Series_duration"]
sns.distplot(Series_duration.reset_index()["Series_duration"],bins = 10)
plt.xticks(np.arange(0,17,1))
plt.show()

# %% [markdown]
# #### looks like majority of the Movie content is around 75 to 125 min long ! and Series/TV Shows are 1 to 3 seasons long .
#
# #### adding longer content may or may not be benifiical
#
# #### below is the data , for Movies and TV shows with highest duration and yet famous.

# %% [markdown]
# ### Maximum Length Content yet Popular , and their Directors :
#
# #### this infomation can be helpful in increasing the watch time on Netflix by producing/adding their Movies/series.

# %%
data.groupby("title")["Series_duration","directors"].aggregate({"Series_duration":"max",
                                                                 "directors":"unique"}).sort_values(by="Series_duration",ascending=False).head(20)
# Out:
#                                     Series_duration          directors
# title
# Grey's Anatomy                                 17.0          [Unknown]
# NCIS                                           15.0          [Unknown]
# Supernatural                                   15.0    [Phil Sgriccia]
# Red vs. Blue                                   13.0          [Unknown]
# Heartland                                      13.0          [Unknown]
# COMEDIANS of the world                         13.0          [Unknown]
# Criminal Minds                                 12.0          [Unknown]
# Trailer Park Boys                              12.0          [Unknown]
# Cheers                                         11.0          [Unknown]
# Frasier                                        11.0          [Unknown]
# Danger Mouse: Classic Collection               10.0          [Unknown]
# Friends                                        10.0          [Unknown]
# Stargate SG-1                                  10.0          [Unknown]
# LEGO Ninjago: Masters of Spinjitzu             10.0          [Unknown]
# The Walking Dead                               10.0          [Unknown]
# Shameless (U.S.)                               10.0          [Unknown]
# Dad's Army                                     10.0          [Unknown]
# The Great British Baking Show                   9.0  [Andy Devonshire]
# The Office (U.S.)                               9.0          [Unknown]
# Forensic Files                                  9.0          [Unknown]

# %%
data.groupby("title")["Movie_duration","directors"].aggregate({"Movie_duration":"max",
                                                                 "directors":"unique"}).sort_values(by="Movie_duration",ascending=False).head(20)
# Out:
#                                                     Movie_duration  \
# title
# Black Mirror: Bandersnatch                                   312.0
# Headspace: Unwind Your Mind                                  273.0
# The School of Mischief                                       253.0
# No Longer kids                                               237.0
# Lock Your Girls In                                           233.0
# Raya and Sakina                                              230.0
# Once Upon a Time in America                                  229.0
# Sangam                                                       228.0
# Lagaan                                                       224.0
# Jodhaa Akbar                                                 214.0
# Seven Souls in the Skull Castle: Season Moon Kagen           212.0
# The Irishman                                                 209.0
# Kabhi Khushi Kabhie Gham                                     209.0
# No Direction Home: Bob Dylan                                 208.0
# The Gospel of Luke                                           205.0
# Fifty Year Old Teenager                                      204.0
# Seven Souls in the Skull Castle: Season Moon Jogen           204.0
# What's Your Raashee?                                         203.0
# The Lord of the Rings: The Return of the King                201.0
# Doctor Zhivago                                               200.0
#
#                                                                    directors
# title
# Black Mirror: Bandersnatch                                         [Unknown]
# Headspace: Unwind Your Mind                                        [Unknown]
# The School of Mischief                              [Houssam El-Din Mustafa]
# No Longer kids                                             [Samir Al Asfory]
# Lock Your Girls In                                       [Fouad El-Mohandes]
# Raya and Sakina                                              [Hussein Kamal]
# Once Upon a Time in America                                   [Sergio Leone]
# Sangam                                                          [Raj Kapoor]
# Lagaan                                                  [Ashutosh Gowariker]
# Jodhaa Akbar                                            [Ashutosh Gowariker]
# Seven Souls in the Skull Castle: Season Moon Kagen          [Hidenori Inoue]
# The Irishman                                               [Martin Scorsese]
# Kabhi Khushi Kabhie Gham                                       [Karan Johar]
# No Direction Home: Bob Dylan                               [Martin Scorsese]
# The Gospel of Luke                                             [David Batty]
# Fifty Year Old Teenager                                    [Fouad Al Shatti]
# Seven Souls in the Skull Castle: Season Moon Jogen          [Hidenori Inoue]
# What's Your Raashee?                                    [Ashutosh Gowariker]
# The Lord of the Rings: The Return of the King                [Peter Jackson]
# Doctor Zhivago                                                  [David Lean]

# %% [markdown]
# # TV shows vs Movie data

# %% [markdown]
# #### creating seperate datasets for Movies and TV Shows for further analysis :

# %%
TV_shows = data.loc[data["type"]=="TV Show"]

# %%
Movies = data.loc[data["type"]=="Movie"]

# %%
TV_shows.columns
# Out:
# Index(['title', 'actors', 'directors', 'countries', 'genres', 'show_id',
#        'type', 'date_added', 'release_year', 'rating', 'serial_no',
#        'year_added', 'month_added', 'Movie_duration', 'Series_duration',
#        'Content_For'],
#       dtype='object')

# %%
TV_shows.groupby("year_added")["title"].nunique()
# Out:
# year_added
# 2008.0      1
# 2013.0      5
# 2014.0      5
# 2015.0     26
# 2016.0    176
# 2017.0    349
# 2018.0    412
# 2019.0    592
# 2020.0    595
# 2021.0    505
# Name: title, dtype: int64

# %%
Movies.groupby("year_added")["title"].nunique()
# Out:
# year_added
# 2008.0       1
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0       6
# 2014.0      19
# 2015.0      56
# 2016.0     253
# 2017.0     839
# 2018.0    1237
# 2019.0    1424
# 2020.0    1284
# 2021.0     993
# Name: title, dtype: int64

# %% [markdown]
# #### plot from above information :

# %%
plt.figure(figsize=(12,8))
plt.bar(Movies.groupby("year_added")["title"].nunique().index,
        Movies.groupby("year_added")["title"].nunique())
plt.bar((TV_shows.groupby("year_added")["title"].nunique().index)+0.15,
        TV_shows.groupby("year_added")["title"].nunique(),
        width=0.5 )
plt.xticks(np.arange(2010,2022),rotation = 0)

plt.title("Count of Content per year")
plt.xlabel("years")
plt.ylabel("Count of Contet")



plt.legend(["Movies","TV_Shows"])
plt.show()

# %% [markdown]
# #### from above bar plot , we can conclude the focus on Movies and TV shows is equal

# %%
tvcount = TV_shows.groupby("countries")["title"].nunique().sort_values(ascending=False).reset_index()

# %%
mcount = Movies.groupby("countries")["title"].nunique().sort_values(ascending=False).reset_index()

# %%
tvVSMovies_per_country = tvcount.merge(mcount,on="countries",how = "outer")

# %%
tvVSMovies_per_country.rename({"title_x":"TV Shows Count",
                              "title_y":"Movies Counts"},axis = 1,inplace=True)

# %%
# tvVSMovies_per_country.head(50)

# %% [markdown]
# ### Movies Counts - TV Shows Count as per Top Countires :

# %%
plt.figure(figsize=(15,10))
plt.bar(tvVSMovies_per_country["countries"].head(30),tvVSMovies_per_country["Movies Counts"].head(30))
plt.bar(tvVSMovies_per_country["countries"].head(30),tvVSMovies_per_country["TV Shows Count"].head(30))
plt.xticks(rotation = 90)
plt.legend(["Movies Counts","TV Shows Count"])

plt.show()

# %% [markdown]
# #### Japan, South Korea, Taiwan, Combodia , Singapore : has more tv shows content compare to movies !
#
# #### We can recommend to focus more on TV shows than Movies in above countires !
#
# #### India and USA has more content of Movies compare to TV shows , and for rest of the countires it is equally distributed .

# %% [markdown]
# ### best time to launch a content :

# %%
data.groupby("month_added")["title"].nunique().sort_values(ascending=False)
# Out:
# month_added
# July         827
# December     813
# September    770
# April        764
# October      760
# August       755
# March        742
# January      738
# June         728
# November     705
# May          632
# February     563
# Name: title, dtype: int64

# %%
data["date_added"]
# Out:
# 0        2021-09-25
# 1        2021-09-24
# 2        2021-09-24
# 3        2021-09-24
# 4        2021-09-24
#             ...
# 201986   2019-03-02
# 201987   2019-03-02
# 201988   2019-03-02
# 201989   2019-03-02
# 201990   2019-03-02
# Name: date_added, Length: 201991, dtype: datetime64[ns]

# %%
data.groupby(data["date_added"].dt.day_name())["title"].nunique().sort_values(ascending=False)
# Out:
# date_added
# Friday       2498
# Thursday     1396
# Wednesday    1288
# Tuesday      1197
# Monday        851
# Saturday      816
# Sunday        751
# Name: title, dtype: int64

# %%
plt.bar(data.groupby(data["date_added"].dt.day_name())["title"].nunique().sort_values(ascending=False).index,
        data.groupby(data["date_added"].dt.day_name())["title"].nunique().sort_values(ascending=False))
plt.xticks(rotation = 45)
plt.show()

# %%
plt.bar(data.groupby(data["date_added"].dt.month_name())["title"].nunique().sort_values(ascending=False).index,
        data.groupby(data["date_added"].dt.month_name())["title"].nunique().sort_values(ascending=False))
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #### best time to launch new content is :  July , September and December months on Friday !

# %% [markdown]
# ### Top directors / actors by Movies and TV shows

# %%
TV_shows.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)
# Out:
# actors
# Unknown               350
# Takahiro Sakurai       25
# Yuki Kaji              19
# Junichi Suwabe         17
# Daisuke Ono            17
# Ai Kayano              17
# Yuichi Nakamura        16
# Jun Fukuyama           15
# Yoshimasa Hosoya       15
# David Attenborough     14
# Vincent Tong           13
# Name: title, dtype: int64

# %%
TV_shows.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)
# Out:
# directors
# Unknown                2446
# Ken Burns                 3
# Alastair Fothergill       3
# Stan Lathan               2
# Joe Berlinger             2
# Name: title, dtype: int64

# %%
Movies.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)
# Out:
# actors
# Unknown             475
# Anupam Kher          42
# Shah Rukh Khan       35
# Naseeruddin Shah     32
# Om Puri              30
# Akshay Kumar         30
# Paresh Rawal         28
# Julie Tejwani        28
# Amitabh Bachchan     28
# Rupa Bhimani         27
# Boman Irani          27
# Name: title, dtype: int64

# %%
Movies.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)
# Out:
# directors
# Unknown                188
# Rajiv Chilaka           22
# Jan Suter               21
# Raúl Campos             19
# Suhas Kadav             16
# Marcus Raboy            15
# Jay Karas               15
# Cathy Garcia-Molina     13
# Martin Scorsese         12
# Jay Chapman             12
# Youssef Chahine         12
# Name: title, dtype: int64

# %% [markdown]
# # Analysing and plotting for Top actors/directors and genres for Top 4 countries

# %% [markdown]
# # `For United States`

# %%
United_States = data.loc[data["countries"] == "United States"]
United_States.head(2)
# Out:
#                     title        actors        directors      countries  \
# 0    Dick Johnson Is Dead       Unknown  Kirsten Johnson  United States
# 179               Sankofa  Kofi Ghanaba     Haile Gerima  United States
#
#             genres show_id   type date_added  release_year rating  serial_no  \
# 0    Documentaries      s1  Movie 2021-09-25          2020  PG-13          0
# 179         Dramas      s8  Movie 2021-09-24          1993  TV-MA          7
#
#      year_added month_added  Movie_duration  Series_duration Content_For
# 0        2021.0   September            90.0              NaN       Teens
# 179      2021.0   September           125.0              NaN      Adults

# %%
United_States.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20)
# Out:
# genres
# Dramas                      835
# Comedies                    680
# Documentaries               511
# Action & Adventure          404
# Independent Movies          390
# Children & Family Movies    390
# Thrillers                   292
# TV Comedies                 258
# TV Dramas                   232
# Romantic Movies             225
# Stand-Up Comedy             216
# Kids' TV                    214
# Horror Movies               201
# Docuseries                  192
# Sci-Fi & Fantasy            181
# International Movies        166
# Music & Musicals            147
# Crime TV Shows              145
# Reality TV                  123
# Sports Movies               113
# Name: title, dtype: int64

# %% [markdown]
# ### top 20 highest watched genres in USA

# %%
plt.figure(figsize=(7,4))
sns.barplot(x = United_States.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20).index ,
            y = United_States.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20))
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per genre")

plt.show()

# %% [markdown]
# ### top 10 actors with maximum content online,  in USA

# %%
United_States.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:]
# Out:
# actors
# Samuel L. Jackson    22
# Tara Strong          22
# Fred Tatasciore      21
# Adam Sandler         20
# Nicolas Cage         19
# James Franco         19
# Morgan Freeman       18
# Seth Rogen           18
# Molly Shannon        17
# Fred Armisen         16
# Name: title, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = United_States.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:].index ,
            y = United_States.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per Actor")
plt.show()

# %% [markdown]
# ### top 10 directors with maximum content online,  in USA

# %%
United_States.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)[1:]
# Out:
# directors
# Marcus Raboy        15
# Jay Karas           15
# Martin Scorsese     12
# Jay Chapman         12
# Steven Spielberg    11
# Don Michael Paul    10
# Shannon Hartman      9
# Ryan Polito          8
# Troy Miller          8
# Robert Rodriguez     8
# Name: title, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = United_States.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)[1:].index ,
            y = United_States.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content Directed by")


plt.show()

# %% [markdown]
# # `For India`

# %%
India = data.loc[data["countries"] == "India"]
India.head(2)
# Out:
#            title      actors directors countries                  genres  \
# 87  Kota Factory  Mayur More   Unknown     India  International TV Shows
# 88  Kota Factory  Mayur More   Unknown     India       Romantic TV Shows
#
#    show_id     type date_added  release_year rating  serial_no  year_added  \
# 87      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
# 88      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
#
#    month_added  Movie_duration  Series_duration Content_For
# 87   September             NaN              2.0      Adults
# 88   September             NaN              2.0      Adults

# %%
India.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20)
# Out:
# genres
# International Movies        864
# Dramas                      662
# Comedies                    323
# Independent Movies          167
# Action & Adventure          137
# Romantic Movies             120
# Music & Musicals             96
# Thrillers                    92
# International TV Shows       66
# Horror Movies                35
# TV Dramas                    28
# Documentaries                27
# TV Comedies                  26
# Children & Family Movies     26
# Sports Movies                17
# Sci-Fi & Fantasy             12
# Romantic TV Shows            12
# Kids' TV                     12
# Classic Movies               11
# Docuseries                    9
# Name: title, dtype: int64

# %% [markdown]
# ### Top 20 genres in India

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = India.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20).index ,
            y = India.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20))
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per genre")

plt.show()

# %% [markdown]
# ### Top 10 actors with highest number of content

# %%
India.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)
# Out:
# actors
# Anupam Kher         40
# Unknown             39
# Shah Rukh Khan      34
# Naseeruddin Shah    31
# Om Puri             29
# Akshay Kumar        29
# Amitabh Bachchan    28
# Paresh Rawal        28
# Boman Irani         27
# Kareena Kapoor      25
# Ajay Devgn          21
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = India.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11).index , 
            y = India.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11))
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per Actor")
plt.show()

# %%
India.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)[1:]
# Out:
# directors
# David Dhawan          9
# Anurag Kashyap        9
# Umesh Mehra           8
# Dibakar Banerjee      7
# Priyadarshan          7
# Ram Gopal Varma       7
# Sooraj R. Barjatya    6
# Imtiaz Ali            6
# Karan Johar           6
# Ashutosh Gowariker    6
# Name: title, dtype: int64

# %% [markdown]
# ### Top 10 directors with highest number of content

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = India.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)[1:].index ,
            y = India.groupby("directors")["title"].nunique().sort_values(ascending=False).head(11)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content Directed by")


plt.show()

# %% [markdown]
# ##### Type of Content in India

# %%
India.groupby("type")["title"].nunique()
# Out:
# type
# Movie      962
# TV Show     84
# Name: title, dtype: int64

# %%
sns.barplot(x = India.groupby("type")["title"].nunique().index , 
           y = India.groupby("type")["title"].nunique())
# Out:
# <AxesSubplot:xlabel='type', ylabel='title'>

# %% [markdown]
# #### Trend of TV shows in India

# %%
IndiaTV_Shows = India.loc[India["type"]=="TV Show"]

# %%
IndiaTV_Shows.columns
# Out:
# Index(['title', 'actors', 'directors', 'countries', 'genres', 'show_id',
#        'type', 'date_added', 'release_year', 'rating', 'serial_no',
#        'year_added', 'month_added', 'Movie_duration', 'Series_duration',
#        'Content_For'],
#       dtype='object')

# %%
IndiaTV_Shows = IndiaTV_Shows.groupby(["title","year_added"]).nunique().reset_index()

# %%
IndiaTV_Shows = IndiaTV_Shows[["title","year_added"]].sort_values(by="year_added")

# %%
IndiaTV_Shows
# Out:
#                             title  year_added
# 26  Fear Files... Har Mod Pe Darr      2017.0
# 29              Gangs of Hassepur      2017.0
# 17                Classic Legends      2017.0
# 60            Pyaar Tune Kya Kiya      2017.0
# 79         The House That Made Me      2017.0
# ..                            ...         ...
# 15                   Chhota Bheem      2021.0
# 14                  Bombay Begums      2021.0
# 4                    Alma Matters      2021.0
# 66               Sab Jholmaal Hai      2021.0
# 83               Zindagi in Short      2021.0
#
# [84 rows x 2 columns]

# %%
IndiaTV_Shows=  IndiaTV_Shows.groupby("year_added").nunique()
IndiaTV_Shows
# Out:
#             title
# year_added
# 2017.0         14
# 2018.0         17
# 2019.0         18
# 2020.0         18
# 2021.0         17

# %%
sns.lineplot(x = IndiaTV_Shows.index,
           y = IndiaTV_Shows["title"])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ###### looks like there were no TV shows on Netflix before 2017 .  After 2017 it was drastically increasing till 2020, and after that trend got slightly decreased , probably because of pandemic situation.
#
# Since the overall trendline of TV shows is increasing in India ! Netflix should focus also on producing more TV series with movies !
#
# Since Most Popular Genre in India is International Movies, it it also suggested to add some international TV shows from USA and UK in NetflixIndia.
#
#
# Here are some recommended celebrities for TV shows :

# %%
IndiaTVShows = India.loc[India["type"]=="TV Show"]
IndiaTVShows.head()
# Out:
#            title          actors directors countries                  genres  \
# 87  Kota Factory      Mayur More   Unknown     India  International TV Shows
# 88  Kota Factory      Mayur More   Unknown     India       Romantic TV Shows
# 89  Kota Factory      Mayur More   Unknown     India             TV Comedies
# 90  Kota Factory  Jitendra Kumar   Unknown     India  International TV Shows
# 91  Kota Factory  Jitendra Kumar   Unknown     India       Romantic TV Shows
#
#    show_id     type date_added  release_year rating  serial_no  year_added  \
# 87      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
# 88      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
# 89      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
# 90      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
# 91      s5  TV Show 2021-09-24          2021  TV-MA          4      2021.0
#
#    month_added  Movie_duration  Series_duration Content_For
# 87   September             NaN              2.0      Adults
# 88   September             NaN              2.0      Adults
# 89   September             NaN              2.0      Adults
# 90   September             NaN              2.0      Adults
# 91   September             NaN              2.0      Adults

# %% [markdown]
# ##### best directors for Indian TV shows

# %%
IndiaTVShows.groupby("directors")["title"].nunique().sort_values(ascending=False)[1:]
# Out:
# directors
# Gautham Vasudev Menon        2
# Anurag Kashyap               1
# Nizar Shafi                  1
# Vijay Roche                  1
# Vignesh Shivan               1
# Vetri Maaran                 1
# Vasanth Sai                  1
# Tharun Bhascker Dhaassyam    1
# Sudha Kongara                1
# Soumendra Padhi              1
# Sarjun                       1
# Sankalp Reddy                1
# Rathindran R Prasad          1
# Priyadarshan                 1
# Patrick Graham               1
# Nag Ashwin                   1
# Arvind Swamy                 1
# Moyoung Jin                  1
# Karthik Subbaraj             1
# Karthik Narain               1
# Hikaru Toda                  1
# Fahad Mustafa                1
# Elaine McMillion Sheldon     1
# Dheeraj Berry                1
# Deepti Kakkar                1
# Chico Pereira                1
# Caroline Sá                  1
# Bumpy                        1
# Bejoy Nambiar                1
# B. V. Nandini Reddy          1
# Vikramaditya Motwane         1
# Name: title, dtype: int64

# %%
IndiaTVShows.groupby("actors")["title"].nunique().sort_values(ascending=False).head(30)
# Out:
# actors
# Unknown                  19
# Nishka Raheja             3
# Rajesh Kava               3
# Aranya Kaur               2
# Rajesh Tailang            2
# Shanoor Mirza             2
# Manish Chaudhary          2
# Sabina Malik              2
# Gagan Arora               2
# Julie Tejwani             2
# Reena Aggarwal            2
# Mona Ambegaonkar          2
# Jitendra Joshi            2
# Ulka Gupta                2
# Anjali                    2
# Shreya Mehta              2
# Radhika Apte              2
# Rupa Bhimani              2
# Siddhant Karnick          2
# Viineet Kumar             2
# Prakash Raj               2
# Sonal Kaushal             2
# Ahsaas Channa             2
# Aahana Kumra              2
# Jigna Bhardwaj            2
# Neeraj Kabi               2
# Chandan Anand             2
# Revathi Pillai            2
# Gautham Vasudev Menon     2
# Rasika Dugal              2
# Name: title, dtype: int64

# %%
# Recommended Genres for Indian TV shows

# %%
IndiaTVShows.groupby("genres")["title"].nunique().sort_values(ascending=False).head(10)
# Out:
# genres
# International TV Shows    66
# TV Dramas                 28
# TV Comedies               26
# Kids' TV                  12
# Romantic TV Shows         12
# Docuseries                 9
# Crime TV Shows             9
# TV Horror                  7
# Reality TV                 6
# TV Action & Adventure      5
# Name: title, dtype: int64

# %% [markdown]
# #### all tv shows in India

# %%
India_TV_Shows  = India.loc[India["type"]=="TV Show"]
India_TV_Shows.groupby("title")["title"].nunique()
# Out:
# title
# 21 Sarfarosh: Saragarhi 1897    1
# 7 (Seven)                       1
# Agent Raghav                    1
# Akbar Birbal                    1
# Alma Matters                    1
#                                ..
# The House That Made Me          1
# The Jungle Book                 1
# Typewriter                      1
# Yeh Meri Family                 1
# Zindagi in Short                1
# Name: title, Length: 84, dtype: int64

# %% [markdown]
# # `For UK`

# %%
UK = data.loc[data["countries"] == "United Kingdom"]

# %%
UK.head(2)
# Out:
#        title        actors     directors       countries              genres  \
# 188  Sankofa  Kofi Ghanaba  Haile Gerima  United Kingdom              Dramas
# 189  Sankofa  Kofi Ghanaba  Haile Gerima  United Kingdom  Independent Movies
#
#     show_id   type date_added  release_year rating  serial_no  year_added  \
# 188      s8  Movie 2021-09-24          1993  TV-MA          7      2021.0
# 189      s8  Movie 2021-09-24          1993  TV-MA          7      2021.0
#
#     month_added  Movie_duration  Series_duration Content_For
# 188   September           125.0              NaN      Adults
# 189   September           125.0              NaN      Adults

# %%
UK.shape
# Out:
# (12945, 16)

# %% [markdown]
# ### Top 20 genres in UK

# %%
UK.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20)
# Out:
# genres
# British TV Shows            225
# Dramas                      196
# International Movies        168
# International TV Shows      128
# Documentaries               127
# Comedies                     91
# Docuseries                   89
# Action & Adventure           84
# Independent Movies           74
# Thrillers                    61
# Crime TV Shows               48
# Children & Family Movies     46
# TV Comedies                  44
# Kids' TV                     43
# Romantic Movies              38
# TV Dramas                    36
# Music & Musicals             36
# Sci-Fi & Fantasy             35
# Reality TV                   35
# Horror Movies                28
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = UK.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20).index ,
            y = UK.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20))
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per genre")

plt.show()

# %% [markdown]
# ### Top 10 Actors in UK

# %%
UK.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:]
# Out:
# actors
# David Attenborough      17
# John Cleese             16
# Michael Palin           14
# Terry Jones             12
# Eric Idle               12
# Terry Gilliam           11
# Graham Chapman          11
# Helena Bonham Carter     9
# Samuel West              9
# Judi Dench               9
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = UK.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:].index ,
            y = UK.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per Actor")
plt.show()

# %% [markdown]
# ### Top 5 directors in UK

# %%
UK.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)[1:]
# Out:
# directors
# Edward Cotterill       4
# Alastair Fothergill    4
# Jerry Rothwell         3
# Martin Campbell        3
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = UK.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)[1:].index ,
            y = UK.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content Directed by")


plt.show()

# %% [markdown]
# ##### TV shows in UK

# %%
UK = data.loc[data["countries"] == "United Kingdom"]
UK.shape
# Out:
# (12945, 16)

# %%
UK.groupby("type")["title"].nunique()
# Out:
# type
# Movie      532
# TV Show    272
# Name: title, dtype: int64

# %%
sns.barplot(x = UK.groupby("type")["title"].nunique().index , 
           y = UK.groupby("type")["title"].nunique())
# Out:
# <AxesSubplot:xlabel='type', ylabel='title'>

# %%
UK_TV_shows = UK.loc[UK["type"]=="TV Show"]

# %%
UK_TV_shows = UK_TV_shows.groupby(["title","year_added"]).nunique().reset_index()

# %%
UK_TV_shows = UK_TV_shows[["title","year_added"]].sort_values(by="year_added")

# %%
UK_TV_shows=  UK_TV_shows.groupby("year_added").nunique()
UK_TV_shows
# Out:
#             title
# year_added
# 2013.0          1
# 2015.0          5
# 2016.0         22
# 2017.0         53
# 2018.0         44
# 2019.0         60
# 2020.0         49
# 2021.0         37

# %% [markdown]
# ##### Trend line for TV Shows in UK

# %%
sns.lineplot(x = UK_TV_shows.index,
           y = UK_TV_shows["title"])
plt.xticks(rotation = 90)
plt.show()

# %%
UK_TV_shows = UK.loc[UK["type"]=="TV Show"]
UK_TV_shows.shape
# Out:
# (4385, 16)

# %%
UK_TV_shows.groupby("directors")["title"].nunique().sort_values(ascending=False)[1:]
# Out:
# directors
# Alastair Fothergill    3
# Tony Collingwood       1
# Toby Haynes            1
# Simon Frederick        1
# Rachel Bell            1
# Philippa Lowthorpe     1
# Noam Murro             1
# Michael Samuels        1
# Michael Cumming        1
# Mark Tonderai          1
# Mark Lewis             1
# Laïla Marrakchi        1
# Juliet May             1
# Jesse Vile             1
# Alan Poul              1
# James Hawes            1
# Jakob Verbruggen       1
# Jakob Schuh            1
# Ian Barber             1
# Houda Benyamina        1
# Greg Tiernan           1
# Gordon Anderson        1
# Ellena Wood            1
# Daniel Kontur          1
# Dan Lucchesi           1
# Damien Chazelle        1
# Andy Devonshire        1
# Ally Pankiw            1
# Jani Lachauer          1
# Name: title, dtype: int64

# %%
UK_TV_shows.groupby("actors")["title"].nunique().sort_values(ascending=False).head(30)[1:]
# Out:
# actors
# David Attenborough    13
# Terry Jones            5
# Graham Chapman         5
# John Cleese            5
# Eric Idle              5
# Michael Palin          5
# Terry Gilliam          4
# Teresa Gallagher       4
# Harriet Walter         4
# Greg Davies            4
# Olivia Colman          4
# Rory Kinnear           4
# Brendan Coyle          4
# Kate Harbour           4
# David Dawson           3
# Ricky Gervais          3
# Paul Hollywood         3
# David Holt             3
# Ruth Bratt             3
# Danny Sapani           3
# Daniel Rigby           3
# David Tennant          3
# Hannah John-Kamen      3
# Nadiya Hussain         3
# Hugh Bonneville        3
# Henry Lloyd-Hughes     3
# Andy Nyman             3
# Bertie Carvel          3
# Siobhan Finneran       3
# Name: title, dtype: int64

# %%
UK_TV_shows.groupby("genres")["title"].nunique().sort_values(ascending=False).head(10)
# Out:
# genres
# British TV Shows          225
# International TV Shows    128
# Docuseries                 89
# Crime TV Shows             48
# TV Comedies                44
# Kids' TV                   43
# TV Dramas                  36
# Reality TV                 35
# Science & Nature TV        27
# Romantic TV Shows          11
# Name: title, dtype: int64

# %% [markdown]
# # `For canada`

# %%
Canada = data.loc[data["countries"] == "Canada"]
Canada.head()
# Out:
#                    title           actors     directors countries  \
# 937  Birth of the Dragon  Billy Magnussen  George Nolfi    Canada
# 938  Birth of the Dragon  Billy Magnussen  George Nolfi    Canada
# 943  Birth of the Dragon         Ron Yuan  George Nolfi    Canada
# 944  Birth of the Dragon         Ron Yuan  George Nolfi    Canada
# 949  Birth of the Dragon      Qu Jingjing  George Nolfi    Canada
#
#                  genres show_id   type date_added  release_year rating  \
# 937  Action & Adventure     s39  Movie 2021-09-16          2017  PG-13
# 938              Dramas     s39  Movie 2021-09-16          2017  PG-13
# 943  Action & Adventure     s39  Movie 2021-09-16          2017  PG-13
# 944              Dramas     s39  Movie 2021-09-16          2017  PG-13
# 949  Action & Adventure     s39  Movie 2021-09-16          2017  PG-13
#
#      serial_no  year_added month_added  Movie_duration  Series_duration  \
# 937         38      2021.0   September            96.0              NaN
# 938         38      2021.0   September            96.0              NaN
# 943         38      2021.0   September            96.0              NaN
# 944         38      2021.0   September            96.0              NaN
# 949         38      2021.0   September            96.0              NaN
#
#     Content_For
# 937       Teens
# 938       Teens
# 943       Teens
# 944       Teens
# 949       Teens

# %%
Canada.shape
# Out:
# (7915, 16)

# %% [markdown]
# ### top 20 genres in Canada

# %%
Canada.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20)
# Out:
# genres
# Comedies                    94
# Dramas                      82
# Children & Family Movies    80
# Kids' TV                    61
# International Movies        60
# Thrillers                   49
# Independent Movies          44
# Action & Adventure          44
# Documentaries               42
# Horror Movies               36
# TV Dramas                   32
# TV Comedies                 30
# Sci-Fi & Fantasy            28
# International TV Shows      25
# Romantic Movies             25
# Crime TV Shows              15
# Music & Musicals            14
# Sports Movies               13
# TV Action & Adventure       12
# Docuseries                  11
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = Canada.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20).index ,
            y = Canada.groupby("genres")["title"].nunique().sort_values(ascending =False).head(20))
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per genre")

plt.show()

# %% [markdown]
# ### Top 10 Actors in Canada

# %%
Canada.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:]
# Out:
# actors
# John Paul Tremblay    14
# Robb Wells            14
# John Dunsworth        12
# Vincent Tong          12
# Ashleigh Ball         12
# Andrea Libman         11
# Michela Luci          11
# Mike Smith            10
# Tara Strong            9
# Cory Doran             9
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = Canada.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:].index ,
            y = Canada.groupby("actors")["title"].nunique().sort_values(ascending=False).head(11)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content per Actor")
plt.show()

# %% [markdown]
# ### Top 10 directors in Canada

# %%
Canada.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)[1:]
# Out:
# directors
# Justin G. Dyck        8
# Mike Clattenburg      5
# Mike Smith            5
# John Paul Tremblay    5
# Name: title, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = Canada.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)[1:].index ,
            y = Canada.groupby("directors")["title"].nunique().sort_values(ascending=False).head(5)[1:])
plt.xticks(rotation = 90)
plt.ylabel("Number of Content Directed by")


plt.show()

# %% [markdown]
# # Apart from Highest Subscribers Countries :
# ## people from other countries can be potentials subscribers :
# ### Those countries are :
#
# Russia
# China
# Germany
# South Korea
# Mexico
# Singapore
# Poland
# United Arab Emirates

# %% [markdown]
# ## recommended actors/directors and genres in countires listed above :

# %%
potential_subscribers_from = ["Russia","China","Germany","South Korea", "Mexico","Singapore","Poland","United Arab Emirates"]

# %%
for countries in potential_subscribers_from:
    print("===============================================")
    print("Country: ",countries)
    print("Recommended Names # Number of movies they have done")
    print("-----------------------------------------------")
    print(data[data["countries"]==countries].groupby("actors")["title"].nunique().sort_values(ascending = False).head(10))
    print("-----------------------------------------------")
    print(data[data["countries"]==countries].groupby("directors")["title"].nunique().sort_values(ascending = False).head(6)[1:])
    print("-----------------------------------------------")
    print(data[data["countries"]==countries].groupby("genres")["title"].nunique().sort_values(ascending = False).head(10))
    print()
# Out:
# ===============================================
# Country:  Russia
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Unknown                   5
# Alexander Petrov          3
# Paulina Andreeva          3
# Eldar Kalimulin           2
# Olga Sutulova             2
# Fillip Gorenshtein        2
# Alyson Leigh Rosenfeld    2
# Erica Schroeder           2
# Dmitry Shevchenko         2
# Kirill Käro               2
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Aleksey German       1
# Aleksey Tsitsilin    1
# Chris Gorak          1
# Gayane Petrosyan     1
# Ilya Naishuller      1
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International TV Shows      10
# TV Dramas                    7
# Kids' TV                     6
# International Movies         6
# Crime TV Shows               6
# Action & Adventure           4
# Dramas                       3
# Documentaries                2
# Children & Family Movies     2
# Sci-Fi & Fantasy             2
# Name: title, dtype: int64
#
# ===============================================
# Country:  China
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Donnie Yen     10
# Jackie Chan     8
# Xing Yu         6
# Unknown         6
# Simon Yam       6
# Chang Chen      5
# Shawn Yue       5
# Iko Uwais       4
# Kent Cheng      4
# Lam Suet        4
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Wilson Yip          5
# Johnnie To          3
# Mark Osborne        2
# Shalini Kantayya    2
# Dante Lam           2
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International Movies        71
# Action & Adventure          63
# International TV Shows      40
# Dramas                      32
# Comedies                    31
# Romantic TV Shows           22
# TV Dramas                   20
# Children & Family Movies    16
# Sci-Fi & Fantasy            13
# TV Comedies                 12
# Name: title, dtype: int64
#
# ===============================================
# Country:  Germany
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Unknown                19
# Daniel Brühl            5
# Sylvester Groth         4
# Wotan Wilke Möhring     4
# Louis Held              4
# David Schütter          4
# Lina Larissa Strahl     4
# Charly Hübner           4
# Michael Maertens        4
# David Attenborough      4
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Detlev Buck                 5
# Fernando González Molina    3
# McG                         2
# Olivier Assayas             2
# Jonathan Mostow             2
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International Movies        94
# Dramas                      80
# Comedies                    42
# International TV Shows      35
# Action & Adventure          33
# Independent Movies          31
# Thrillers                   28
# Documentaries               21
# TV Dramas                   19
# Children & Family Movies    17
# Name: title, dtype: int64
#
# ===============================================
# Country:  South Korea
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Sung Dong-il        6
# Cho Seong-ha        5
# Nam Joo-hyuk        5
# Park Shin-hye       5
# Park Hae-joon       5
# Kim Won-hae         5
# Kyeong-yeong Lee    5
# Jung Hae-in         4
# Unknown             4
# Cho Han-cheul       4
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Sang-ho Yeon       2
# Thomas Astruc      2
# Shin Won-ho        2
# Bong Joon Ho       2
# Mark A.Z. Dippé    2
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International TV Shows    152
# Korean TV Shows           132
# Romantic TV Shows          77
# International Movies       44
# TV Dramas                  38
# Dramas                     26
# Crime TV Shows             24
# TV Comedies                19
# Action & Adventure         17
# Comedies                   17
# Name: title, dtype: int64
#
# ===============================================
# Country:  Mexico
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Unknown                   16
# Humberto Busto             6
# Arcelia Ramírez            6
# Cassandra Ciangherotti     6
# Damián Alcázar             5
# Sofía Niño de Rivera       5
# Fernando Becerril          5
# Alfonso Herrera            5
# José Sefami                5
# Tenoch Huerta              4
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Jan Suter          12
# Raúl Campos        10
# Alex Díaz           3
# Alfonso Cuarón      3
# Antonio Serrano     2
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International Movies         70
# Spanish-Language TV Shows    47
# Dramas                       44
# International TV Shows       43
# Crime TV Shows               32
# Comedies                     24
# Independent Movies           23
# Documentaries                18
# Stand-Up Comedy              18
# TV Dramas                    12
# Name: title, dtype: int64
#
# ===============================================
# Country:  Singapore
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Zhang Zhenhuan    7
# Tay Ping Hui      6
# Rui En            5
# Elvin Ng          4
# Rebecca Lim       4
# Jeanette Aw       4
# Xiang Yun         3
# Jesseca Liu       3
# Paige Chua        3
# Romeo Tan         3
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Daniel Lee        1
# Lana Wachowski    1
# Tom Tykwer        1
# Steve Cheng       1
# Sam Loh           1
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International TV Shows    19
# TV Dramas                 15
# International Movies      14
# Dramas                     7
# Action & Adventure         5
# Crime TV Shows             5
# Romantic TV Shows          5
# Kids' TV                   3
# Thrillers                  3
# Horror Movies              3
# Name: title, dtype: int64
#
# ===============================================
# Country:  Poland
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Agata Kulesza          3
# Robert Więckiewicz     3
# Unknown                2
# Bartłomiej Topa        2
# Danuta Stenka          2
# Piotr Fronczewski      2
# Piotr Cyrwus           2
# Paulina Gałązka        2
# Grażyna Szapołowska    2
# Helena Sujecka         2
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Stanisław Różewicz     2
# Patryk Vega            2
# Aleksey German         1
# Alexandros Avranas     1
# Wojciech Marczewski    1
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International Movies      25
# Dramas                    24
# International TV Shows     9
# TV Dramas                  8
# Thrillers                  6
# Comedies                   6
# Crime TV Shows             6
# Independent Movies         5
# Romantic Movies            4
# Action & Adventure         3
# Name: title, dtype: int64
#
# ===============================================
# Country:  United Arab Emirates
# Recommended Names # Number of movies they have done
# -----------------------------------------------
# actors
# Yaser Alneyadi       4
# Ali Suliman          3
# Ahd                  3
# Mansour Al Felei     3
# Khaled Al-Nuaimi     3
# Muhammed Murshed     3
# Samer al Masri       2
# Ali Almarzouqi       2
# Mohamed Alkendi      2
# Saeed Al-Sheryani    2
# Name: title, dtype: int64
# -----------------------------------------------
# directors
# Ali F. Mostafa         2
# Ibrahim Bin Mohamed    2
# Ahmed Zein             2
# Simon Wells            1
# Shazia Ali Khan        1
# Name: title, dtype: int64
# -----------------------------------------------
# genres
# International Movies        26
# Dramas                      19
# Comedies                    11
# Documentaries                7
# Thrillers                    5
# Children & Family Movies     4
# Action & Adventure           3
# Independent Movies           3
# Sci-Fi & Fantasy             3
# Horror Movies                2
# Name: title, dtype: int64

# %% [markdown]
# ## Top genres per top countires :

# %%
for cntry in top_20_countires[:11]:
    print()
    print("<<",cntry,">>")
    print(data.groupby("countries")["genres"].get_group(cntry).value_counts().head().index)
    print()
    print()
# Out:
# << United States >>
# Index(['Comedies', 'Dramas', 'Children & Family Movies', 'Action & Adventure',
#        'Independent Movies'],
#       dtype='object')
#
#
#
# << India >>
# Index(['International Movies', 'Dramas', 'Comedies', 'Independent Movies',
#        'Action & Adventure'],
#       dtype='object')
#
#
#
# << Unknown >>
# Index(['International TV Shows', 'International Movies', 'Dramas', 'TV Dramas',
#        'Comedies'],
#       dtype='object')
#
#
#
# << United Kingdom >>
# Index(['Dramas', 'British TV Shows', 'International Movies', 'Comedies',
#        'International TV Shows'],
#       dtype='object')
#
#
#
# << Canada >>
# Index(['Comedies', 'Children & Family Movies', 'Dramas', 'Kids' TV',
#        'International Movies'],
#       dtype='object')
#
#
#
# << France >>
# Index(['International Movies', 'Dramas', 'Independent Movies', 'Comedies',
#        'International TV Shows'],
#       dtype='object')
#
#
#
# << Japan >>
# Index(['International TV Shows', 'Anime Series', 'Action & Adventure',
#        'Anime Features', 'International Movies'],
#       dtype='object')
#
#
#
# << Spain >>
# Index(['International Movies', 'Dramas', 'International TV Shows', 'Comedies',
#        'Spanish-Language TV Shows'],
#       dtype='object')
#
#
#
# << South Korea >>
# Index(['International TV Shows', 'Korean TV Shows', 'Romantic TV Shows',
#        'International Movies', 'TV Dramas'],
#       dtype='object')
#
#
#
# << Germany >>
# Index(['Dramas', 'International Movies', 'Comedies', 'Action & Adventure',
#        'International TV Shows'],
#       dtype='object')
#
#
#
# << Mexico >>
# Index(['Spanish-Language TV Shows', 'International Movies',
#        'International TV Shows', 'Crime TV Shows', 'Dramas'],
#       dtype='object')

# %% [markdown]
# # year wise best top 5 genres :

# %%
years = np.arange(2010,2022,1)

# %%
years
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021])

# %%
data.groupby("year_added").get_group(2021).groupby("genres")["title"].nunique().sort_values(ascending = False).head()
# Out:
# genres
# Dramas                    412
# International Movies      408
# Comedies                  299
# International TV Shows    229
# Action & Adventure        196
# Name: title, dtype: int64

# %%
for yr in years :
    print()
    print(yr)
    print(data.groupby("year_added").get_group(yr).groupby("genres")["title"].nunique().sort_values(ascending = False).head())
    print("=======================")
# Out:
# 2010
# genres
# Cult Movies      1
# Horror Movies    1
# Name: title, dtype: int64
# =======================
#
# 2011
# genres
# Dramas                      13
# Sports Movies                2
# Children & Family Movies     1
# Faith & Spirituality         1
# International Movies         1
# Name: title, dtype: int64
# =======================
#
# 2012
# genres
# Comedies                    2
# Children & Family Movies    1
# Documentaries               1
# Name: title, dtype: int64
# =======================
#
# 2013
# genres
# Stand-Up Comedy             4
# TV Dramas                   4
# Children & Family Movies    2
# Crime TV Shows              2
# Comedies                    1
# Name: title, dtype: int64
# =======================
#
# 2014
# genres
# Documentaries               8
# Children & Family Movies    4
# Stand-Up Comedy             4
# TV Comedies                 3
# TV Dramas                   3
# Name: title, dtype: int64
# =======================
#
# 2015
# genres
# Stand-Up Comedy             13
# Documentaries               13
# Comedies                    12
# Dramas                      12
# Children & Family Movies    11
# Name: title, dtype: int64
# =======================
#
# 2016
# genres
# International TV Shows    86
# International Movies      82
# Documentaries             68
# Dramas                    65
# Comedies                  48
# Name: title, dtype: int64
# =======================
#
# 2017
# genres
# International Movies      395
# Dramas                    293
# Documentaries             206
# International TV Shows    205
# Comedies                  177
# Name: title, dtype: int64
# =======================
#
# 2018
# genres
# International Movies      668
# Dramas                    531
# Comedies                  297
# International TV Shows    214
# Action & Adventure        173
# Name: title, dtype: int64
# =======================
#
# 2019
# genres
# International Movies      610
# Dramas                    564
# Comedies                  420
# International TV Shows    335
# Action & Adventure        202
# Name: title, dtype: int64
# =======================
#
# 2020
# genres
# International Movies      575
# Dramas                    535
# Comedies                  416
# International TV Shows    277
# Romantic Movies           173
# Name: title, dtype: int64
# =======================
#
# 2021
# genres
# Dramas                    412
# International Movies      408
# Comedies                  299
# International TV Shows    229
# Action & Adventure        196
# Name: title, dtype: int64
# =======================

# %%
data
# Out:
#                        title                 actors        directors  \
# 0       Dick Johnson Is Dead                Unknown  Kirsten Johnson
# 1              Blood & Water             Ama Qamata          Unknown
# 2              Blood & Water             Ama Qamata          Unknown
# 3              Blood & Water             Ama Qamata          Unknown
# 4              Blood & Water            Khosi Ngema          Unknown
# ...                      ...                    ...              ...
# 201986                Zubaan         Anita Shabdish      Mozez Singh
# 201987                Zubaan         Anita Shabdish      Mozez Singh
# 201988                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201989                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201990                Zubaan  Chittaranjan Tripathy      Mozez Singh
#
#             countries                  genres show_id     type date_added  \
# 0       United States           Documentaries      s1    Movie 2021-09-25
# 1        South Africa  International TV Shows      s2  TV Show 2021-09-24
# 2        South Africa               TV Dramas      s2  TV Show 2021-09-24
# 3        South Africa            TV Mysteries      s2  TV Show 2021-09-24
# 4        South Africa  International TV Shows      s2  TV Show 2021-09-24
# ...               ...                     ...     ...      ...        ...
# 201986          India    International Movies   s8807    Movie 2019-03-02
# 201987          India        Music & Musicals   s8807    Movie 2019-03-02
# 201988          India                  Dramas   s8807    Movie 2019-03-02
# 201989          India    International Movies   s8807    Movie 2019-03-02
# 201990          India        Music & Musicals   s8807    Movie 2019-03-02
#
#         release_year rating  serial_no  year_added month_added  \
# 0               2020  PG-13          0      2021.0   September
# 1               2021  TV-MA          1      2021.0   September
# 2               2021  TV-MA          1      2021.0   September
# 3               2021  TV-MA          1      2021.0   September
# 4               2021  TV-MA          1      2021.0   September
# ...              ...    ...        ...         ...         ...
# 201986          2015  TV-14       8806      2019.0       March
# 201987          2015  TV-14       8806      2019.0       March
# 201988          2015  TV-14       8806      2019.0       March
# 201989          2015  TV-14       8806      2019.0       March
# 201990          2015  TV-14       8806      2019.0       March
#
#         Movie_duration  Series_duration Content_For
# 0                 90.0              NaN       Teens
# 1                  NaN              2.0      Adults
# 2                  NaN              2.0      Adults
# 3                  NaN              2.0      Adults
# 4                  NaN              2.0      Adults
# ...                ...              ...         ...
# 201986           111.0              NaN       Teens
# 201987           111.0              NaN       Teens
# 201988           111.0              NaN       Teens
# 201989           111.0              NaN       Teens
# 201990           111.0              NaN       Teens
#
# [201991 rows x 16 columns]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                               Unknown        Unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            Unknown        Unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating  \
# 0    2021-09-25          2020  PG-13
# 1    2021-09-24          2021  TV-MA
# 2    2021-09-24          2021  TV-MA
# 3    2021-09-24          2021  TV-MA
# 4    2021-09-24          2021  TV-MA
# ...         ...           ...    ...
# 8802 2019-11-20          2007      R
# 8803 2019-07-01          2018  TV-Y7
# 8804 2019-11-01          2009      R
# 8805 2020-01-11          2006     PG
# 8806 2019-03-02          2015  TV-14
#
#                                               listed_in  serial_no  \
# 0                                         Documentaries          0
# 1       International TV Shows, TV Dramas, TV Mysteries          1
# 2     Crime TV Shows, International TV Shows, TV Act...          2
# 3                                Docuseries, Reality TV          3
# 4     International TV Shows, Romantic TV Shows, TV ...          4
# ...                                                 ...        ...
# 8802                     Cult Movies, Dramas, Thrillers       8802
# 8803             Kids' TV, Korean TV Shows, TV Comedies       8803
# 8804                            Comedies, Horror Movies       8804
# 8805                 Children & Family Movies, Comedies       8805
# 8806     Dramas, International Movies, Music & Musicals       8806
#
#       year_added month_added  Movie_duration  Series_duration Content_For
# 0         2021.0   September            90.0              NaN       Teens
# 1         2021.0   September             NaN              2.0      Adults
# 2         2021.0   September             NaN              1.0      Adults
# 3         2021.0   September             NaN              1.0      Adults
# 4         2021.0   September             NaN              2.0      Adults
# ...          ...         ...             ...              ...         ...
# 8802      2019.0    November           158.0              NaN      Adults
# 8803      2019.0        July             NaN              2.0  Older Kids
# 8804      2019.0    November            88.0              NaN      Adults
# 8805      2020.0     January            88.0              NaN  Older Kids
# 8806      2019.0       March           111.0              NaN       Teens
#
# [8807 rows x 16 columns]

# %%
data
# Out:
#                        title                 actors        directors  \
# 0       Dick Johnson Is Dead                Unknown  Kirsten Johnson
# 1              Blood & Water             Ama Qamata          Unknown
# 2              Blood & Water             Ama Qamata          Unknown
# 3              Blood & Water             Ama Qamata          Unknown
# 4              Blood & Water            Khosi Ngema          Unknown
# ...                      ...                    ...              ...
# 201986                Zubaan         Anita Shabdish      Mozez Singh
# 201987                Zubaan         Anita Shabdish      Mozez Singh
# 201988                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201989                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201990                Zubaan  Chittaranjan Tripathy      Mozez Singh
#
#             countries                  genres show_id     type date_added  \
# 0       United States           Documentaries      s1    Movie 2021-09-25
# 1        South Africa  International TV Shows      s2  TV Show 2021-09-24
# 2        South Africa               TV Dramas      s2  TV Show 2021-09-24
# 3        South Africa            TV Mysteries      s2  TV Show 2021-09-24
# 4        South Africa  International TV Shows      s2  TV Show 2021-09-24
# ...               ...                     ...     ...      ...        ...
# 201986          India    International Movies   s8807    Movie 2019-03-02
# 201987          India        Music & Musicals   s8807    Movie 2019-03-02
# 201988          India                  Dramas   s8807    Movie 2019-03-02
# 201989          India    International Movies   s8807    Movie 2019-03-02
# 201990          India        Music & Musicals   s8807    Movie 2019-03-02
#
#         release_year rating  serial_no  year_added month_added  \
# 0               2020  PG-13          0      2021.0   September
# 1               2021  TV-MA          1      2021.0   September
# 2               2021  TV-MA          1      2021.0   September
# 3               2021  TV-MA          1      2021.0   September
# 4               2021  TV-MA          1      2021.0   September
# ...              ...    ...        ...         ...         ...
# 201986          2015  TV-14       8806      2019.0       March
# 201987          2015  TV-14       8806      2019.0       March
# 201988          2015  TV-14       8806      2019.0       March
# 201989          2015  TV-14       8806      2019.0       March
# 201990          2015  TV-14       8806      2019.0       March
#
#         Movie_duration  Series_duration Content_For
# 0                 90.0              NaN       Teens
# 1                  NaN              2.0      Adults
# 2                  NaN              2.0      Adults
# 3                  NaN              2.0      Adults
# 4                  NaN              2.0      Adults
# ...                ...              ...         ...
# 201986           111.0              NaN       Teens
# 201987           111.0              NaN       Teens
# 201988           111.0              NaN       Teens
# 201989           111.0              NaN       Teens
# 201990           111.0              NaN       Teens
#
# [201991 rows x 16 columns]

# %%
genre_year = data.groupby(["genres","year_added"])["title"].nunique().reset_index()
genre_year
# Out:
#                  genres  year_added  title
# 0    Action & Adventure      2014.0      1
# 1    Action & Adventure      2015.0      2
# 2    Action & Adventure      2016.0     18
# 3    Action & Adventure      2017.0     97
# 4    Action & Adventure      2018.0    173
# ..                  ...         ...    ...
# 326           Thrillers      2017.0     68
# 327           Thrillers      2018.0    111
# 328           Thrillers      2019.0    135
# 329           Thrillers      2020.0    133
# 330           Thrillers      2021.0    112
#
# [331 rows x 3 columns]

# %%
most_popular_genres
# Out:
# Index(['International Movies', 'Dramas', 'Comedies', 'International TV Shows',
#        'Documentaries', 'Action & Adventure', 'TV Dramas',
#        'Independent Movies', 'Children & Family Movies', 'Romantic Movies',
#        'TV Comedies', 'Thrillers', 'Crime TV Shows', 'Kids' TV', 'Docuseries',
#        'Music & Musicals', 'Romantic TV Shows', 'Horror Movies',
#        'Stand-Up Comedy', 'Reality TV'],
#       dtype='object', name='genres')

# %%
genre_year.loc[genre_year["genres"]=="Comedies"]
# Out:
#       genres  year_added  title
# 52  Comedies      2012.0      2
# 53  Comedies      2013.0      1
# 54  Comedies      2014.0      2
# 55  Comedies      2015.0     12
# 56  Comedies      2016.0     48
# 57  Comedies      2017.0    177
# 58  Comedies      2018.0    297
# 59  Comedies      2019.0    420
# 60  Comedies      2020.0    416
# 61  Comedies      2021.0    299

# %%
plt.bar(genre_year.loc[genre_year["genres"]=="TV Comedies"]["year_added"],
        genre_year.loc[genre_year["genres"]=="TV Comedies"]["title"]
       )
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(genre_year.loc[genre_year["genres"]=="Documentaries"]["year_added"],
        genre_year.loc[genre_year["genres"]=="Documentaries"]["title"]
       )
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(genre_year.loc[genre_year["genres"]=="Documentaries"]["year_added"],
        genre_year.loc[genre_year["genres"]=="Documentaries"]["title"]
       )
# Out:
# <BarContainer object of 10 artists>
